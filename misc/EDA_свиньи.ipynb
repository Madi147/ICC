# %% [markdown]
# ## Time-series Analysis & Stationarity Check

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf
from pylab import rcParams
from IPython.display import display
import math

import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter("ignore", category=InterpolationWarning)

# %% [markdown]
# #### Data preparation

# %%
df = pd.read_excel("Данные-рус Обработанные.xlsx")
df.head(5)
# Out:
#    Unnamed: 0           Unnamed: 1               Unnamed: 2  \
# 0         NaN                  NaN                      NaN
# 1         NaN                  NaN                      NaN
# 2  Показатель  Категория хозяйства                   Регион
# 3         КРС   Сельхозпредприятия     РЕСПУБЛИКА КАЗАХСТАН
# 4         КРС   Сельхозпредприятия      АКМОЛИНСКАЯ ОБЛАСТЬ
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2  2015-01-01 00:00:00  2015-02-01 00:00:00  2015-03-01 00:00:00
# 3              3400.96               3685.9              4154.43
# 4               514.75               497.95               863.93
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2  2015-04-01 00:00:00  2015-05-01 00:00:00  2015-06-01 00:00:00
# 3              5203.94              5084.05              6718.83
# 4               667.81               633.39               600.86
#
#             Unnamed: 9  ...         Unnamed: 113         Unnamed: 114  \
# 0                  NaN  ...                  NaN                  NaN
# 1                  NaN  ...                  NaN                  NaN
# 2  2015-07-01 00:00:00  ...  2024-03-01 00:00:00  2024-04-01 00:00:00
# 3              4235.03  ...              9703.45             11165.56
# 4               875.47  ...               978.41              1071.35
#
#           Unnamed: 115         Unnamed: 116         Unnamed: 117  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2  2024-05-01 00:00:00  2024-06-01 00:00:00  2024-07-01 00:00:00
# 3              8179.14             24407.52              9835.22
# 4              1067.76              1119.61               898.07
#
#           Unnamed: 118         Unnamed: 119         Unnamed: 120  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2  2024-08-01 00:00:00  2024-09-01 00:00:00  2024-10-01 00:00:00
# 3             11955.41             16955.56             10638.42
# 4                 1382              1133.36              1073.27
#
#           Unnamed: 121         Unnamed: 122
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# 2  2024-11-01 00:00:00  2024-12-01 00:00:00
# 3              9612.92              21521.5
# 4              1118.19              1332.88
#
# [5 rows x 123 columns]

# %%
# remove first two rows (blank)
df = df.drop(index=df.index[:2]).reset_index(drop=True)
df.head(5)
# Out:
#    Unnamed: 0           Unnamed: 1               Unnamed: 2  \
# 0  Показатель  Категория хозяйства                   Регион
# 1         КРС   Сельхозпредприятия     РЕСПУБЛИКА КАЗАХСТАН
# 2         КРС   Сельхозпредприятия      АКМОЛИНСКАЯ ОБЛАСТЬ
# 3         КРС   Сельхозпредприятия      АКТЮБИНСКАЯ ОБЛАСТЬ
# 4         КРС   Сельхозпредприятия      АЛМАТИНСКАЯ ОБЛАСТЬ
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0  2015-01-01 00:00:00  2015-02-01 00:00:00  2015-03-01 00:00:00
# 1              3400.96               3685.9              4154.43
# 2               514.75               497.95               863.93
# 3               554.41               504.35               493.56
# 4                178.3               362.86               352.49
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# 0  2015-04-01 00:00:00  2015-05-01 00:00:00  2015-06-01 00:00:00
# 1              5203.94              5084.05              6718.83
# 2               667.81               633.39               600.86
# 3               445.51               585.79               316.47
# 4               451.79               228.32               708.84
#
#             Unnamed: 9  ...         Unnamed: 113         Unnamed: 114  \
# 0  2015-07-01 00:00:00  ...  2024-03-01 00:00:00  2024-04-01 00:00:00
# 1              4235.03  ...              9703.45             11165.56
# 2               875.47  ...               978.41              1071.35
# 3               469.49  ...              1520.51              1747.09
# 4               280.55  ...              1055.43               110.45
#
#           Unnamed: 115         Unnamed: 116         Unnamed: 117  \
# 0  2024-05-01 00:00:00  2024-06-01 00:00:00  2024-07-01 00:00:00
# 1              8179.14             24407.52              9835.22
# 2              1067.76              1119.61               898.07
# 3                915.8              1851.96               932.63
# 4               188.15               172.63               112.31
#
#           Unnamed: 118         Unnamed: 119         Unnamed: 120  \
# 0  2024-08-01 00:00:00  2024-09-01 00:00:00  2024-10-01 00:00:00
# 1             11955.41             16955.56             10638.42
# 2                 1382              1133.36              1073.27
# 3               945.11              1142.92              1637.64
# 4               134.99              1212.02               260.02
#
#           Unnamed: 121         Unnamed: 122
# 0  2024-11-01 00:00:00  2024-12-01 00:00:00
# 1              9612.92              21521.5
# 2              1118.19              1332.88
# 3              1180.54              1045.69
# 4               129.38               159.66
#
# [5 rows x 123 columns]

# %%
# Set the first row as column labels
df.columns = df.iloc[0]  # Assign first row as header
df = df[1:].reset_index(drop=True)  # Drop the first row and reset index
df.sample(5)
# Out:
# 0     Показатель                    Категория хозяйства  \
# 142       Свиньи                     Сельхозпредприятия
# 201       Лошади                     Сельхозпредприятия
# 96   Овцы и козы  Крестьянские или фермерские хозяйства
# 482         Яйца                     Сельхозпредприятия
# 423       Молоко  Крестьянские или фермерские хозяйства
#
# 0                               Регион 2015-01-01 00:00:00  \
# 142              МАНГИСТАУСКАЯ ОБЛАСТЬ                 NaN
# 201                АЛМАТИНСКАЯ ОБЛАСТЬ                7.37
# 96                КОСТАНАЙСКАЯ ОБЛАСТЬ               24.56
# 482                     ОБЛАСТЬ ҰЛЫТАУ                 нет
# 423      ЗАПАДНО0КАЗАХСТАНСКАЯ ОБЛАСТЬ               628.7
#
# 0   2015-02-01 00:00:00 2015-03-01 00:00:00 2015-04-01 00:00:00  \
# 142                 NaN                 NaN                 NaN
# 201                6.58               17.99               12.35
# 96                28.12               23.96                54.4
# 482                 нет                 нет                 нет
# 423               986.4              1850.7              4641.1
#
# 0   2015-05-01 00:00:00 2015-06-01 00:00:00 2015-07-01 00:00:00  ...  \
# 142                 NaN                 NaN                 NaN  ...
# 201               16.29               21.25               14.99  ...
# 96                16.29               15.64               21.29  ...
# 482                 нет                 нет                 нет  ...
# 423             10108.3              6762.8              6762.8  ...
#
# 0   2024-03-01 00:00:00 2024-04-01 00:00:00 2024-05-01 00:00:00  \
# 142                 NaN                 NaN                 NaN
# 201                1.35                 8.2                5.77
# 96                 19.2                24.3                11.7
# 482               763.2               686.8               532.9
# 423              2411.7              6315.3              8755.5
#
# 0   2024-06-01 00:00:00 2024-07-01 00:00:00 2024-08-01 00:00:00  \
# 142                 NaN                 NaN                 NaN
# 201                   2                1.57                1.24
# 96                 18.1                12.6                 5.9
# 482               486.3               489.9               458.3
# 423             10589.5              5833.2                2947
#
# 0   2024-09-01 00:00:00 2024-10-01 00:00:00 2024-11-01 00:00:00  \
# 142                 NaN                 NaN                 NaN
# 201                0.67                 1.5                4.75
# 96                 32.9                21.1                27.3
# 482               381.5               348.5                 337
# 423              3371.7              2367.6              2344.8
#
# 0   2024-12-01 00:00:00
# 142                 NaN
# 201                3.68
# 96                 43.5
# 482               598.4
# 423              1422.2
#
# [5 rows x 123 columns]

# %%
df["Регион"].unique()
# Out:
# array(['РЕСПУБЛИКА КАЗАХСТАН', '    АКМОЛИНСКАЯ ОБЛАСТЬ',
#        '    АКТЮБИНСКАЯ ОБЛАСТЬ', '    АЛМАТИНСКАЯ ОБЛАСТЬ',
#        '    АТЫРАУСКАЯ ОБЛАСТЬ', '    ЗАПАДНО0КАЗАХСТАНСКАЯ ОБЛАСТЬ',
#        '    ЖАМБЫЛСКАЯ ОБЛАСТЬ', '    КАРАГАНДИНСКАЯ ОБЛАСТЬ',
#        '    КОСТАНАЙСКАЯ ОБЛАСТЬ', '    КЫЗЫЛОРДИНСКАЯ ОБЛАСТЬ',
#        '    МАНГИСТАУСКАЯ ОБЛАСТЬ', '    ЮЖНО0КАЗАХСТАНСКАЯ ОБЛАСТЬ',
#        '    ПАВЛОДАРСКАЯ ОБЛАСТЬ', '    СЕВЕРО0КАЗАХСТАНСКАЯ ОБЛАСТЬ',
#        '    ВОСТОЧНО0КАЗАХСТАНСКАЯ ОБЛАСТЬ', '    ГАСТАНА', '    ГАЛМАТЫ',
#        '    ГШЫМКЕНТ', '    ТУРКЕСТАНСКАЯ ОБЛАСТЬ', '    ОБЛАСТЬ ЖЕТІСУ',
#        '    ОБЛАСТЬ ҰЛЫТАУ', '    ОБЛАСТЬ АБАЙ'], dtype=object)

# %%
df["Регион"] = df["Регион"].str.strip()
rename_dict = {
    "ВОСТОЧНО0КАЗАХСТАНСКАЯ ОБЛАСТЬ": "ВОСТОЧНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ", 
    "ГАЛМАТЫ": "ГОРОД АЛМАТЫ",
    "ГАСТАНА": "ГОРОД АСТАНА",
    "ГШЫМКЕНТ": "ГОРОД ШЫМКЕНТ",  
    "ЗАПАДНО0КАЗАХСТАНСКАЯ ОБЛАСТЬ": "ЗАПАДНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ",
    "СЕВЕРО0КАЗАХСТАНСКАЯ ОБЛАСТЬ": "СЕВЕРО-КАЗАХСТАНСКАЯ ОБЛАСТЬ",
    "ЮЖНО0КАЗАХСТАНСКАЯ ОБЛАСТЬ": "ЮЖНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ",  
}

# Rename regions in the index
df["Регион"] = df["Регион"].replace(rename_dict)

df["Регион"].unique()
# Out:
# array(['РЕСПУБЛИКА КАЗАХСТАН', 'АКМОЛИНСКАЯ ОБЛАСТЬ',
#        'АКТЮБИНСКАЯ ОБЛАСТЬ', 'АЛМАТИНСКАЯ ОБЛАСТЬ', 'АТЫРАУСКАЯ ОБЛАСТЬ',
#        'ЗАПАДНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ', 'ЖАМБЫЛСКАЯ ОБЛАСТЬ',
#        'КАРАГАНДИНСКАЯ ОБЛАСТЬ', 'КОСТАНАЙСКАЯ ОБЛАСТЬ',
#        'КЫЗЫЛОРДИНСКАЯ ОБЛАСТЬ', 'МАНГИСТАУСКАЯ ОБЛАСТЬ',
#        'ЮЖНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ', 'ПАВЛОДАРСКАЯ ОБЛАСТЬ',
#        'СЕВЕРО-КАЗАХСТАНСКАЯ ОБЛАСТЬ', 'ВОСТОЧНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ',
#        'ГОРОД АСТАНА', 'ГОРОД АЛМАТЫ', 'ГОРОД ШЫМКЕНТ',
#        'ТУРКЕСТАНСКАЯ ОБЛАСТЬ', 'ОБЛАСТЬ ЖЕТІСУ', 'ОБЛАСТЬ ҰЛЫТАУ',
#        'ОБЛАСТЬ АБАЙ'], dtype=object)

# %%
# Filter the df
df = df[df['Показатель'] == "Свиньи"]
# df = df.drop(columns=["Показатель", "Категория хозяйства"])
df.sample(5)
# Out:
# 0   Показатель  Категория хозяйства                 Регион  \
# 152     Свиньи   Сельхозпредприятия         ОБЛАСТЬ ҰЛЫТАУ
# 142     Свиньи   Сельхозпредприятия  МАНГИСТАУСКАЯ ОБЛАСТЬ
# 194     Свиньи  Хозяйства населения  ТУРКЕСТАНСКАЯ ОБЛАСТЬ
# 196     Свиньи  Хозяйства населения         ОБЛАСТЬ ҰЛЫТАУ
# 149     Свиньи   Сельхозпредприятия          ГОРОД ШЫМКЕНТ
#
# 0   2015-01-01 00:00:00 2015-02-01 00:00:00 2015-03-01 00:00:00  \
# 152                 нет                 нет                 нет
# 142                 NaN                 NaN                 NaN
# 194                 нет                 нет                 нет
# 196                 нет                 нет                 нет
# 149                 нет                 нет                 нет
#
# 0   2015-04-01 00:00:00 2015-05-01 00:00:00 2015-06-01 00:00:00  \
# 152                 нет                 нет                 нет
# 142                 NaN                 NaN                 NaN
# 194                 нет                 нет                 нет
# 196                 нет                 нет                 нет
# 149                 нет                 нет                 нет
#
# 0   2015-07-01 00:00:00  ... 2024-03-01 00:00:00 2024-04-01 00:00:00  \
# 152                 нет  ...                 NaN                 NaN
# 142                 NaN  ...                 NaN                 NaN
# 194                 нет  ...                 2.5                 0.7
# 196                 нет  ...                 0.9                 NaN
# 149                 нет  ...                   0                   0
#
# 0   2024-05-01 00:00:00 2024-06-01 00:00:00 2024-07-01 00:00:00  \
# 152                 NaN                 NaN                 NaN
# 142                 NaN                 NaN                 NaN
# 194                   1                 NaN                 5.1
# 196                 1.1                 NaN                 2.6
# 149                   0                   0                   0
#
# 0   2024-08-01 00:00:00 2024-09-01 00:00:00 2024-10-01 00:00:00  \
# 152                 NaN                 NaN                 NaN
# 142                 NaN                 NaN                 NaN
# 194                 2.2                 0.5                 1.6
# 196                 0.4                 1.6                 NaN
# 149                   0                   0                   0
#
# 0   2024-11-01 00:00:00 2024-12-01 00:00:00
# 152                 NaN                 NaN
# 142                 NaN                 NaN
# 194                 5.9                 5.7
# 196                 NaN                 3.6
# 149                   0                   0
#
# [5 rows x 123 columns]

# %%
# Sum only the last two columns, grouped by "Регион"
df_sum = df.groupby("Регион")[df.columns[3:]].sum().reset_index()
df_sum
# Out:
# 0                           Регион 2015-01-01 00:00:00 2015-02-01 00:00:00  \
# 0              АКМОЛИНСКАЯ ОБЛАСТЬ              581.58              664.65
# 1              АКТЮБИНСКАЯ ОБЛАСТЬ               779.4              799.54
# 2              АЛМАТИНСКАЯ ОБЛАСТЬ             1151.45             1592.85
# 3               АТЫРАУСКАЯ ОБЛАСТЬ                0.48                0.32
# 4   ВОСТОЧНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ              512.91               561.7
# 5                     ГОРОД АЛМАТЫ                 4.5                1.53
# 6                     ГОРОД АСТАНА                0.41                0.41
# 7                    ГОРОД ШЫМКЕНТ           нетнетнет           нетнетнет
# 8               ЖАМБЫЛСКАЯ ОБЛАСТЬ              525.65              499.24
# 9    ЗАПАДНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ              224.83              266.79
# 10          КАРАГАНДИНСКАЯ ОБЛАСТЬ               779.6              957.34
# 11            КОСТАНАЙСКАЯ ОБЛАСТЬ             4112.71             2784.19
# 12          КЫЗЫЛОРДИНСКАЯ ОБЛАСТЬ               16.93               19.55
# 13           МАНГИСТАУСКАЯ ОБЛАСТЬ                7.44                2.56
# 14                    ОБЛАСТЬ АБАЙ           нетнетнет           нетнетнет
# 15                  ОБЛАСТЬ ЖЕТІСУ           нетнетнет           нетнетнет
# 16                  ОБЛАСТЬ ҰЛЫТАУ           нетнетнет           нетнетнет
# 17            ПАВЛОДАРСКАЯ ОБЛАСТЬ             1033.47             1214.76
# 18            РЕСПУБЛИКА КАЗАХСТАН            11941.62            11676.76
# 19    СЕВЕРО-КАЗАХСТАНСКАЯ ОБЛАСТЬ             2083.77             2196.55
# 20           ТУРКЕСТАНСКАЯ ОБЛАСТЬ           нетнетнет           нетнетнет
# 21      ЮЖНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ              108.15              114.78
#
# 0  2015-03-01 00:00:00 2015-04-01 00:00:00 2015-05-01 00:00:00  \
# 0               910.44               845.5              669.93
# 1               971.94              877.85               742.7
# 2              2274.55             1882.65             1133.55
# 3                 1.12                1.48                2.28
# 4               624.13               564.5              492.39
# 5                  4.5                5.49                2.79
# 6                  0.5                1.04                1.04
# 7            нетнетнет           нетнетнет           нетнетнет
# 8               451.43              609.02              419.91
# 9               335.82              215.48              277.54
# 10             1119.23             1231.99             1392.27
# 11              602.16              464.39              546.36
# 12               15.33                8.37                4.33
# 13                3.76                1.44                5.76
# 14           нетнетнет           нетнетнет           нетнетнет
# 15           нетнетнет           нетнетнет           нетнетнет
# 16           нетнетнет           нетнетнет           нетнетнет
# 17              819.62              770.41              936.47
# 18             9954.33              9481.5             8623.15
# 19              1691.1             1652.45             1437.63
# 20           нетнетнет           нетнетнет           нетнетнет
# 21               128.7              349.44               558.2
#
# 0  2015-06-01 00:00:00 2015-07-01 00:00:00 2015-08-01 00:00:00  \
# 0              2122.07             1942.69              864.65
# 1                885.3              812.09               775.0
# 2              2328.75              392.25             1623.05
# 3                 3.94                5.34                   0
# 4              1162.33              664.94              558.15
# 5                    0                   0                3.51
# 6                 0.91                0.92                2.45
# 7            нетнетнет           нетнетнет           нетнетнет
# 8               813.93              470.64              486.83
# 9               286.39              255.92              192.53
# 10             1349.55               901.3             1288.39
# 11              733.47              877.82             2171.56
# 12               14.52               12.23                7.81
# 13                 5.1                0.88                 3.2
# 14           нетнетнет           нетнетнет           нетнетнет
# 15           нетнетнет           нетнетнет           нетнетнет
# 16           нетнетнет           нетнетнет           нетнетнет
# 17              850.53              662.68              556.98
# 18            10764.18            11182.94            10424.78
# 19               79.69             4011.24             1765.96
# 20           нетнетнет           нетнетнет           нетнетнет
# 21               127.7               172.0              124.71
#
# 0  2015-09-01 00:00:00  ... 2024-03-01 00:00:00 2024-04-01 00:00:00  \
# 0              1035.89  ...              523.64              515.15
# 1               854.78  ...               133.2                97.8
# 2              2137.15  ...                73.6               115.3
# 3                  0.7  ...                   0                   0
# 4               473.77  ...              426.38              407.34
# 5                    0  ...                   0                   0
# 6                 1.02  ...                   0                   0
# 7            нетнетнет  ...                 2.0                 2.3
# 8               429.95  ...                24.9                29.4
# 9               260.71  ...               233.8               190.8
# 10             1052.53  ...              724.31              791.73
# 11             1703.32  ...               162.8                66.3
# 12               10.99  ...                 3.6                   5
# 13               23.12  ...                   0                   0
# 14           нетнетнет  ...                86.7               124.6
# 15           нетнетнет  ...              500.52              191.82
# 16           нетнетнет  ...                 0.9                   0
# 17              503.06  ...             1451.52              1837.4
# 18              9755.8  ...             5736.88              5873.0
# 19             1141.84  ...             1386.32             1497.36
# 20           нетнетнет  ...                 2.5                 0.7
# 21              126.97  ...           нетнетнет           нетнетнет
#
# 0  2024-05-01 00:00:00 2024-06-01 00:00:00 2024-07-01 00:00:00  \
# 0               309.94              797.36              945.29
# 1                 11.4               126.9                41.5
# 2               105.35              101.19              101.72
# 3                    0                   0                   0
# 4                371.6              614.91              369.74
# 5                    0                   0                   0
# 6                    0                   0                   0
# 7                  1.1                 1.5                 1.3
# 8                 13.3                79.9                19.0
# 9                231.3              145.13               165.3
# 10              799.86              804.37              745.53
# 11              133.58              166.34              174.56
# 12                 4.4                 2.6                 3.1
# 13                   0                   0                   0
# 14               196.9                25.7                40.9
# 15              169.13              599.72              175.68
# 16                 1.1                   0                 2.6
# 17              1684.2             1563.17             1520.87
# 18             5234.96             6958.43             6119.64
# 19              1200.8             1929.55             1807.66
# 20                   1                   0                 5.1
# 21           нетнетнет           нетнетнет           нетнетнет
#
# 0  2024-08-01 00:00:00 2024-09-01 00:00:00 2024-10-01 00:00:00  \
# 0               553.23              566.96              496.85
# 1                  7.6                56.7                80.7
# 2               236.84              466.77              290.34
# 3                  3.8                   0                   0
# 4               463.17              399.19              304.73
# 5                    0                   0                   0
# 6                    0                 0.1                   0
# 7                  0.9                 5.4                10.8
# 8                 13.9                51.0                27.4
# 9                167.7               169.6               174.8
# 10              731.19              799.44              776.04
# 11              332.33               272.7              434.95
# 12                 4.4                 4.6                13.6
# 13                   0                   0                   0
# 14                23.4                57.0                51.4
# 15              189.78              234.52               269.1
# 16                 0.4                 1.6                   0
# 17             1617.42             1524.98             1793.94
# 18             5531.93             5634.19             6303.81
# 19             1183.77             1023.24             1577.77
# 20                 2.2                 0.5                 1.6
# 21           нетнетнет           нетнетнет           нетнетнет
#
# 0  2024-11-01 00:00:00 2024-12-01 00:00:00
# 0               488.59              480.05
# 1                 25.5                20.6
# 2                  9.0               156.2
# 3                    0                   0
# 4                310.4              513.21
# 5                  1.4                   0
# 6                    0                 0.1
# 7                  6.3                20.2
# 8                 52.0                26.9
# 9                155.9               168.9
# 10              871.68              934.66
# 11              517.61              528.19
# 12                 8.3                 5.2
# 13                   0                   0
# 14                81.2               152.1
# 15               222.1               175.4
# 16                   0                 3.6
# 17              1735.7             1662.16
# 18             5734.92             6873.08
# 19             1243.23              2020.1
# 20                 5.9                 5.7
# 21           нетнетнет           нетнетнет
#
# [22 rows x 121 columns]

# %%
# convert date columns to datetime format
df_sum.columns = list(df_sum.columns[:1]) + list(pd.to_datetime(df_sum.columns[-120:]))
df_sum = df_sum.rename(columns={col: col.strftime("%Y-%m-%d") for col in df_sum.columns[-120:]})
df_sum.sample(5)
# Out:
#                   Регион 2015-01-01 2015-02-01 2015-03-01 2015-04-01  \
# 1    АКТЮБИНСКАЯ ОБЛАСТЬ      779.4     799.54     971.94     877.85
# 2    АЛМАТИНСКАЯ ОБЛАСТЬ    1151.45    1592.85    2274.55    1882.65
# 16        ОБЛАСТЬ ҰЛЫТАУ  нетнетнет  нетнетнет  нетнетнет  нетнетнет
# 11  КОСТАНАЙСКАЯ ОБЛАСТЬ    4112.71    2784.19     602.16     464.39
# 6           ГОРОД АСТАНА       0.41       0.41        0.5       1.04
#
#    2015-05-01 2015-06-01 2015-07-01 2015-08-01 2015-09-01  ... 2024-03-01  \
# 1       742.7      885.3     812.09      775.0     854.78  ...      133.2
# 2     1133.55    2328.75     392.25    1623.05    2137.15  ...       73.6
# 16  нетнетнет  нетнетнет  нетнетнет  нетнетнет  нетнетнет  ...        0.9
# 11     546.36     733.47     877.82    2171.56    1703.32  ...      162.8
# 6        1.04       0.91       0.92       2.45       1.02  ...          0
#
#    2024-04-01 2024-05-01 2024-06-01 2024-07-01 2024-08-01 2024-09-01  \
# 1        97.8       11.4      126.9       41.5        7.6       56.7
# 2       115.3     105.35     101.19     101.72     236.84     466.77
# 16          0        1.1          0        2.6        0.4        1.6
# 11       66.3     133.58     166.34     174.56     332.33      272.7
# 6           0          0          0          0          0        0.1
#
#    2024-10-01 2024-11-01 2024-12-01
# 1        80.7       25.5       20.6
# 2      290.34        9.0      156.2
# 16          0          0        3.6
# 11     434.95     517.61     528.19
# 6           0          0        0.1
#
# [5 rows x 121 columns]

# %%
# Replace "нетнетнет" with NaN for easier handling
df_sum.replace("нетнетнет", np.nan, inplace=True)

# Convert all values to numeric, keeping NaNs
df_sum_numeric = df_sum.set_index("Регион").apply(pd.to_numeric, errors="coerce")

# Create heatmap: 1 for missing values, 0 for present values
missing_heatmap = df_sum_numeric.isna()

# Plot heatmap
plt.figure(figsize=(16, 8))
sns.heatmap(missing_heatmap, cmap="coolwarm", cbar=False, linewidths=0.5)
plt.title('Missing Values Heatmap - Свиньи (Сумма)')
plt.xlabel("Time Periods")
plt.ylabel("Regions")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_17084\2323452730.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_sum.replace("нетнетнет", np.nan, inplace=True)

# %%
# Convert from wide format to long format
df_sum_melted = df_sum.melt(id_vars=["Регион"], var_name="Месяц", value_name="Объем")
df_sum_melted.sample(5)
# Out:
#                               Регион       Месяц    Объем
# 2035            КОСТАНАЙСКАЯ ОБЛАСТЬ  2022-09-01  1042.20
# 493    ЗАПАДНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ  2016-11-01   340.72
# 2534  ВОСТОЧНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ  2024-08-01   463.17
# 1590                    ГОРОД АСТАНА  2021-01-01     0.00
# 2297   ЗАПАДНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ  2023-09-01   139.26

# %%
# Convert date column to datetime
df_sum_melted["Месяц"] = pd.to_datetime(df_sum_melted["Месяц"])

# Set index for time-series analysis
df_sum_melted = df_sum_melted.sort_values(["Регион", "Месяц"]).set_index(["Регион", "Месяц"])

df_sum_melted
# Out:
#                                         Объем
# Регион                     Месяц
# АКМОЛИНСКАЯ ОБЛАСТЬ        2015-01-01  581.58
#                            2015-02-01  664.65
#                            2015-03-01  910.44
#                            2015-04-01  845.50
#                            2015-05-01  669.93
# ...                                       ...
# ЮЖНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ 2024-08-01     NaN
#                            2024-09-01     NaN
#                            2024-10-01     NaN
#                            2024-11-01     NaN
#                            2024-12-01     NaN
#
# [2640 rows x 1 columns]

# %%
# Replace "нет" with NaN
df_sum_melted = df_sum_melted.replace("нетнетнет", np.nan)
df_sum_melted.isna().groupby("Регион").mean() * 100
# Out:
#                                     Объем
# Регион
# АКМОЛИНСКАЯ ОБЛАСТЬ              0.000000
# АКТЮБИНСКАЯ ОБЛАСТЬ              0.000000
# АЛМАТИНСКАЯ ОБЛАСТЬ              0.000000
# АТЫРАУСКАЯ ОБЛАСТЬ               0.000000
# ВОСТОЧНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ   0.000000
# ГОРОД АЛМАТЫ                     0.000000
# ГОРОД АСТАНА                     0.000000
# ГОРОД ШЫМКЕНТ                   34.166667
# ЖАМБЫЛСКАЯ ОБЛАСТЬ               0.000000
# ЗАПАДНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ    0.000000
# КАРАГАНДИНСКАЯ ОБЛАСТЬ           0.000000
# КОСТАНАЙСКАЯ ОБЛАСТЬ             0.000000
# КЫЗЫЛОРДИНСКАЯ ОБЛАСТЬ           0.000000
# МАНГИСТАУСКАЯ ОБЛАСТЬ            0.000000
# ОБЛАСТЬ АБАЙ                    74.166667
# ОБЛАСТЬ ЖЕТІСУ                  74.166667
# ОБЛАСТЬ ҰЛЫТАУ                  74.166667
# ПАВЛОДАРСКАЯ ОБЛАСТЬ             0.000000
# РЕСПУБЛИКА КАЗАХСТАН             0.000000
# СЕВЕРО-КАЗАХСТАНСКАЯ ОБЛАСТЬ     0.000000
# ТУРКЕСТАНСКАЯ ОБЛАСТЬ           34.166667
# ЮЖНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ      65.833333

# %%
# Filter the df
df_shp = df[(df['Показатель'] == "Свиньи") & (df['Категория хозяйства'] == "Сельхозпредприятия")]
df_shp = df_shp.drop(columns=["Показатель", "Категория хозяйства"])
df_shp = df_shp.sort_values(by="Регион", ascending=True)

df_shp.sample(5)
# Out:
# 0                          Регион 2015-01-01 00:00:00 2015-02-01 00:00:00  \
# 145  СЕВЕРО-КАЗАХСТАНСКАЯ ОБЛАСТЬ              273.97               63.91
# 149                 ГОРОД ШЫМКЕНТ                 нет                 нет
# 151                ОБЛАСТЬ ЖЕТІСУ                 нет                 нет
# 136            АТЫРАУСКАЯ ОБЛАСТЬ                0.48                0.32
# 144          ПАВЛОДАРСКАЯ ОБЛАСТЬ               670.9              731.41
#
# 0   2015-03-01 00:00:00 2015-04-01 00:00:00 2015-05-01 00:00:00  \
# 145              589.75              227.47              104.54
# 149                 нет                 нет                 нет
# 151                 нет                 нет                 нет
# 136                0.32                1.48                2.28
# 144              733.24              445.25               647.8
#
# 0   2015-06-01 00:00:00 2015-07-01 00:00:00 2015-08-01 00:00:00  \
# 145               30.15               18.16               15.44
# 149                 нет                 нет                 нет
# 151                 нет                 нет                 нет
# 136                2.44                4.64                   0
# 144               549.3               343.2              299.75
#
# 0   2015-09-01 00:00:00  ... 2024-03-01 00:00:00 2024-04-01 00:00:00  \
# 145              102.27  ...              922.12             1051.26
# 149                 нет  ...                   0                   0
# 151                 нет  ...              167.32              153.32
# 136                   0  ...                   0                   0
# 144               297.4  ...             1331.62              1712.3
#
# 0   2024-05-01 00:00:00 2024-06-01 00:00:00 2024-07-01 00:00:00  \
# 145               802.8             1767.05              688.36
# 149                   0                   0                   0
# 151              105.43               88.12              106.28
# 136                   0                   0                   0
# 144              1546.8             1431.07             1326.17
#
# 0   2024-08-01 00:00:00 2024-09-01 00:00:00 2024-10-01 00:00:00  \
# 145              818.77              741.54              670.57
# 149                   0                   0                   0
# 151               78.68              114.62               100.1
# 136                   0                   0                   0
# 144             1430.12             1456.88             1631.14
#
# 0   2024-11-01 00:00:00 2024-12-01 00:00:00
# 145              734.43                1294
# 149                   0                   0
# 151                95.3               133.8
# 136                   0                   0
# 144              1472.4             1510.16
#
# [5 rows x 121 columns]

# %%
# Replace "нетнетнет" with NaN for easier handling
df_shp.replace("нет", np.nan, inplace=True)

# Convert all values to numeric, keeping NaNs
df_shp_numeric = df_shp.set_index("Регион").apply(pd.to_numeric, errors="coerce")

# Create heatmap: 1 for missing values, 0 for present values
missing_heatmap = df_shp_numeric.isna()

# Plot heatmap
plt.figure(figsize=(16, 8))
sns.heatmap(missing_heatmap, cmap="coolwarm", cbar=False, linewidths=0.5)
plt.title('Missing Values Heatmap - Свиньи, Сельхозпредприятия')
plt.xlabel("Time Periods")
plt.ylabel("Regions")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_17084\1558762382.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_shp.replace("нет", np.nan, inplace=True)

# %%
# Filter the df
df_kfh = df[(df['Показатель'] == "Свиньи") & (df['Категория хозяйства'] == "Крестьянские или фермерские хозяйства")]
df_kfh = df_kfh.drop(columns=["Показатель", "Категория хозяйства"])
df_kfh = df_kfh.sort_values(by="Регион", ascending=True)

df_kfh.sample(5)
# Out:
# 0                        Регион 2015-01-01 00:00:00 2015-02-01 00:00:00  \
# 170                ГОРОД АЛМАТЫ                 NaN                 NaN
# 162        КОСТАНАЙСКАЯ ОБЛАСТЬ               27.95               27.08
# 165  ЮЖНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ                27.3                23.1
# 174              ОБЛАСТЬ ҰЛЫТАУ                 нет                 нет
# 164       МАНГИСТАУСКАЯ ОБЛАСТЬ                7.44                2.56
#
# 0   2015-03-01 00:00:00 2015-04-01 00:00:00 2015-05-01 00:00:00  \
# 170                 NaN                 NaN                 NaN
# 162               61.33               11.65                6.72
# 165                51.3               117.5               246.5
# 174                 нет                 нет                 нет
# 164                3.76                1.44                5.76
#
# 0   2015-06-01 00:00:00 2015-07-01 00:00:00 2015-08-01 00:00:00  \
# 170                 NaN                 NaN                 NaN
# 162               18.64               18.95                8.83
# 165               15.75                33.1                10.4
# 174                 нет                 нет                 нет
# 164                 5.1                0.88                 3.2
#
# 0   2015-09-01 00:00:00  ... 2024-03-01 00:00:00 2024-04-01 00:00:00  \
# 170                 NaN  ...                 NaN                 NaN
# 162                9.23  ...                14.5                 6.1
# 165                41.4  ...                 нет                 нет
# 174                 нет  ...                   0                   0
# 164               23.12  ...                   0                   0
#
# 0   2024-05-01 00:00:00 2024-06-01 00:00:00 2024-07-01 00:00:00  \
# 170                 NaN                 NaN                 NaN
# 162                   3                18.6                17.8
# 165                 нет                 нет                 нет
# 174                   0                   0                   0
# 164                   0                   0                   0
#
# 0   2024-08-01 00:00:00 2024-09-01 00:00:00 2024-10-01 00:00:00  \
# 170                 NaN                 NaN                 NaN
# 162                 9.9                 6.9                18.5
# 165                 нет                 нет                 нет
# 174                   0                   0                   0
# 164                   0                   0                   0
#
# 0   2024-11-01 00:00:00 2024-12-01 00:00:00
# 170                 NaN                 NaN
# 162                22.1                15.7
# 165                 нет                 нет
# 174                   0                   0
# 164                   0                   0
#
# [5 rows x 121 columns]

# %%
# Replace "нетнетнет" with NaN for easier handling
df_kfh.replace("нет", np.nan, inplace=True)

# Convert all values to numeric, keeping NaNs
df_kfh_numeric = df_kfh.set_index("Регион").apply(pd.to_numeric, errors="coerce")

# Create heatmap: 1 for missing values, 0 for present values
missing_heatmap = df_kfh_numeric.isna()

# Plot heatmap
plt.figure(figsize=(16, 8))
sns.heatmap(missing_heatmap, cmap="coolwarm", cbar=False, linewidths=0.5)
plt.title('Missing Values Heatmap - Свиньи, Крестьянские или фермерские хозяйства')
plt.xlabel("Time Periods")
plt.ylabel("Regions")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_17084\893947625.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_kfh.replace("нет", np.nan, inplace=True)

# %%
# Filter the df
df_hn = df[(df['Показатель'] == "Свиньи") & (df['Категория хозяйства'] == "Хозяйства населения")]
df_hn = df_hn.drop(columns=["Показатель", "Категория хозяйства"])
df_hn = df_hn.sort_values(by="Регион", ascending=True)

df_hn.sample(5)
# Out:
# 0                        Регион 2015-01-01 00:00:00 2015-02-01 00:00:00  \
# 187  ЮЖНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ                52.2                47.4
# 197                ОБЛАСТЬ АБАЙ                 нет                 нет
# 183      КАРАГАНДИНСКАЯ ОБЛАСТЬ              147.08              159.57
# 194       ТУРКЕСТАНСКАЯ ОБЛАСТЬ                 нет                 нет
# 182          ЖАМБЫЛСКАЯ ОБЛАСТЬ              143.05                84.8
#
# 0   2015-03-01 00:00:00 2015-04-01 00:00:00 2015-05-01 00:00:00  \
# 187                42.8               63.84                  59
# 197                 нет                 нет                 нет
# 183              235.41              244.09              473.16
# 194                 нет                 нет                 нет
# 182                80.4              100.64               41.41
#
# 0   2015-06-01 00:00:00 2015-07-01 00:00:00 2015-08-01 00:00:00  \
# 187               80.45                88.4               47.31
# 197                 нет                 нет                 нет
# 183              446.84               98.48              480.92
# 194                 нет                 нет                 нет
# 182              265.72                38.7               34.25
#
# 0   2015-09-01 00:00:00  ... 2024-03-01 00:00:00 2024-04-01 00:00:00  \
# 187                20.2  ...                 нет                 нет
# 197                 нет  ...                47.3               122.4
# 183              141.03  ...                65.6               100.2
# 194                 нет  ...                 2.5                 0.7
# 182               65.48  ...                24.9                10.9
#
# 0   2024-05-01 00:00:00 2024-06-01 00:00:00 2024-07-01 00:00:00  \
# 187                 нет                 нет                 нет
# 197               180.4                15.3                11.8
# 183               192.3                 108               111.9
# 194                   1                 NaN                 5.1
# 182                12.6                36.2                16.6
#
# 0   2024-08-01 00:00:00 2024-09-01 00:00:00 2024-10-01 00:00:00  \
# 187                 нет                 нет                 нет
# 197                13.9                42.3                45.3
# 183               142.7               184.3               170.5
# 194                 2.2                 0.5                 1.6
# 182                   8                31.7                19.7
#
# 0   2024-11-01 00:00:00 2024-12-01 00:00:00
# 187                 нет                 нет
# 197                77.4                 152
# 183               103.2               292.2
# 194                 5.9                 5.7
# 182                34.4                14.7
#
# [5 rows x 121 columns]

# %%
# Replace "нетнетнет" with NaN for easier handling
df_hn.replace("нет", np.nan, inplace=True)

# Convert all values to numeric, keeping NaNs
df_hn_numeric = df_hn.set_index("Регион").apply(pd.to_numeric, errors="coerce")

# Create heatmap: 1 for missing values, 0 for present values
missing_heatmap = df_hn_numeric.isna()

# Plot heatmap
plt.figure(figsize=(16, 8))
sns.heatmap(missing_heatmap, cmap="coolwarm", cbar=False, linewidths=0.5)
plt.title('Missing Values Heatmap - Свиньи, Хозяйства населения')
plt.xlabel("Time Periods")
plt.ylabel("Regions")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_17084\692633755.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_hn.replace("нет", np.nan, inplace=True)

# %%
df_sum_melted
# Out:
#                                         Объем
# Регион                     Месяц
# АКМОЛИНСКАЯ ОБЛАСТЬ        2015-01-01  581.58
#                            2015-02-01  664.65
#                            2015-03-01  910.44
#                            2015-04-01  845.50
#                            2015-05-01  669.93
# ...                                       ...
# ЮЖНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ 2024-08-01     NaN
#                            2024-09-01     NaN
#                            2024-10-01     NaN
#                            2024-11-01     NaN
#                            2024-12-01     NaN
#
# [2640 rows x 1 columns]

# %%
# Reset index if needed
df_stats = df_sum_melted.reset_index()

# Calculate basic descriptive stats for each region
region_stats = df_stats.groupby("Регион")["Объем"].agg([
    "count", "min", "max", "mean", "median", "std"
]).rename(columns={
    "count": "Кол-во значений",
    "min": "Мин.",
    "max": "Макс.",
    "mean": "Среднее",
    "median": "Медиана",
    "std": "Ст. откл."
})

# Display result
display(region_stats.sort_values(by="Среднее", ascending=False))
# Out:
#                                 Кол-во значений     Мин.     Макс.  \
# Регион
# РЕСПУБЛИКА КАЗАХСТАН                        120  5234.96  17236.17
# СЕВЕРО-КАЗАХСТАНСКАЯ ОБЛАСТЬ                120    50.96   5342.27
# КОСТАНАЙСКАЯ ОБЛАСТЬ                        120    66.30   4642.20
# ПАВЛОДАРСКАЯ ОБЛАСТЬ                        120   503.06   2072.85
# КАРАГАНДИНСКАЯ ОБЛАСТЬ                      120   516.62   1905.12
# АКМОЛИНСКАЯ ОБЛАСТЬ                         120   309.94   2723.75
# АЛМАТИНСКАЯ ОБЛАСТЬ                         120     9.00   2328.75
# ВОСТОЧНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ              120   279.53   1162.33
# АКТЮБИНСКАЯ ОБЛАСТЬ                         120     7.53   1171.66
# ЗАПАДНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ               120    63.75    388.77
# ЖАМБЫЛСКАЯ ОБЛАСТЬ                          120    13.30    813.93
# ОБЛАСТЬ ЖЕТІСУ                               31    12.82    599.72
# ЮЖНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ                   41    55.33    558.20
# ОБЛАСТЬ АБАЙ                                 31    14.00    275.00
# ТУРКЕСТАНСКАЯ ОБЛАСТЬ                        79     0.00    227.40
# КЫЗЫЛОРДИНСКАЯ ОБЛАСТЬ                      120     2.60     68.60
# ГОРОД ШЫМКЕНТ                                79     0.90     30.33
# ОБЛАСТЬ ҰЛЫТАУ                               31     0.00     39.10
# МАНГИСТАУСКАЯ ОБЛАСТЬ                       120     0.00     23.12
# ГОРОД АЛМАТЫ                                120     0.00     11.70
# АТЫРАУСКАЯ ОБЛАСТЬ                          120     0.00      7.30
# ГОРОД АСТАНА                                120     0.00      3.07
#
#                                     Среднее   Медиана    Ст. откл.
# Регион
# РЕСПУБЛИКА КАЗАХСТАН            9626.846250  9342.595  2666.791077
# СЕВЕРО-КАЗАХСТАНСКАЯ ОБЛАСТЬ    2113.454833  1796.285  1088.531941
# КОСТАНАЙСКАЯ ОБЛАСТЬ            1516.704833   824.505  1289.047118
# ПАВЛОДАРСКАЯ ОБЛАСТЬ            1290.474750  1271.530   344.876591
# КАРАГАНДИНСКАЯ ОБЛАСТЬ          1032.791500  1007.910   239.142097
# АКМОЛИНСКАЯ ОБЛАСТЬ             1010.156167   858.985   489.435315
# АЛМАТИНСКАЯ ОБЛАСТЬ              736.345917   562.375   544.069855
# ВОСТОЧНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ   644.911750   634.610   191.350362
# АКТЮБИНСКАЯ ОБЛАСТЬ              537.502250   777.200   431.795669
# ЗАПАДНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ    227.035333   228.150    66.421867
# ЖАМБЫЛСКАЯ ОБЛАСТЬ               219.194167   148.345   187.008110
# ОБЛАСТЬ ЖЕТІСУ                   205.040323   176.400   150.291208
# ЮЖНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ       156.601707   134.700    90.426836
# ОБЛАСТЬ АБАЙ                      91.140323    75.400    65.381457
# ТУРКЕСТАНСКАЯ ОБЛАСТЬ             45.686962    46.200    40.934663
# КЫЗЫЛОРДИНСКАЯ ОБЛАСТЬ            13.884000    14.015     7.784159
# ГОРОД ШЫМКЕНТ                      6.251013     4.200     6.259079
# ОБЛАСТЬ ҰЛЫТАУ                     3.718387     1.100     8.000633
# МАНГИСТАУСКАЯ ОБЛАСТЬ              2.260667     0.840     3.161036
# ГОРОД АЛМАТЫ                       1.013750     0.000     1.871228
# АТЫРАУСКАЯ ОБЛАСТЬ                 0.686833     0.000     1.547909
# ГОРОД АСТАНА                       0.272250     0.000     0.525909

# %%
# Filter for national level
national_data = df_stats[df_stats["Регион"] == "РЕСПУБЛИКА КАЗАХСТАН"].copy()

# Ensure 'Месяц' is datetime
national_data["Месяц"] = pd.to_datetime(national_data["Месяц"])

# Create time index as integer (months since start)
national_data = national_data.sort_values("Месяц")
national_data["t"] = range(len(national_data))  # 0, 1, 2, ..., N

# Trend line
coeffs = np.polyfit(national_data["t"], national_data["Объем"], deg=1)
trend = np.poly1d(coeffs)

# Moving Averages
national_data["MA_12"] = national_data["Объем"].rolling(window=12, center=True).mean()

# Plot
plt.figure(figsize=(14, 6))

# Actual data
plt.plot(national_data["Месяц"], national_data["Объем"], label="Фактические данные", color="steelblue")

# Trend line
plt.plot(national_data["Месяц"], trend(national_data["t"]), linestyle="--", color="red", label="Линейный тренд")

# Moving Averages
plt.plot(national_data["Месяц"], national_data["MA_12"], linestyle=":", color="green", label="Скользящее среднее (12 мес.)")

# Labels and style
plt.title("Свиньи, РЕСПУБЛИКА КАЗАХСТАН — Временной ряд с трендом и скользящими средними")
plt.xlabel("Месяц")
plt.ylabel("Объем")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Aggregate by year (sum)
national_data["Год"] = national_data["Месяц"].dt.year
annual_data = national_data.groupby("Год")["Объем"].sum().reset_index()

# Plot
plt.figure(figsize=(10, 5))

# Actual yearly data
plt.plot(annual_data["Год"], annual_data["Объем"], marker='o', label="Годовые суммы", color="steelblue")

# Labels and style
plt.title("Свиньи, РЕСПУБЛИКА КАЗАХСТАН — Годовые данные")
plt.xlabel("Год")
plt.ylabel("Суммарный объем за год")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# # Filter for national level
# aktobe_data = df_stats[df_stats["Регион"] == "АКТЮБИНСКАЯ ОБЛАСТЬ"].copy()

# # Ensure 'Месяц' is datetime
# aktobe_data["Месяц"] = pd.to_datetime(aktobe_data["Месяц"])

# # Create time index as integer (months since start)
# aktobe_data = aktobe_data.sort_values("Месяц")
# aktobe_data["t"] = range(len(aktobe_data))  # 0, 1, 2, ..., N

# # Trend line
# coeffs = np.polyfit(aktobe_data["t"], aktobe_data["Объем"], deg=1)
# trend = np.poly1d(coeffs)

# # Moving Averages
# aktobe_data["MA_12"] = aktobe_data["Объем"].rolling(window=12, center=True).mean()

# # Plot
# plt.figure(figsize=(14, 6))

# # Actual data
# plt.plot(aktobe_data["Месяц"], aktobe_data["Объем"], label="Фактические данные", color="steelblue")

# # Trend line
# plt.plot(aktobe_data["Месяц"], trend(aktobe_data["t"]), linestyle="--", color="red", label="Линейный тренд")

# # Moving Averages
# plt.plot(aktobe_data["Месяц"], aktobe_data["MA_12"], linestyle=":", color="green", label="Скользящее среднее (12 мес.)")

# # Labels and style
# plt.title("АКТЮБИНСКАЯ ОБЛАСТЬ — Временной ряд с трендом и скользящими средними")
# plt.xlabel("Месяц")
# plt.ylabel("Объем")
# plt.xticks(rotation=45)
# plt.grid(True)
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
# # Filter for national level
# akmola_data = df_stats[df_stats["Регион"] == "АКМОЛИНСКАЯ ОБЛАСТЬ"].copy()

# # Ensure 'Месяц' is datetime
# akmola_data["Месяц"] = pd.to_datetime(akmola_data["Месяц"])

# # Create time index as integer (months since start)
# akmola_data = akmola_data.sort_values("Месяц")
# akmola_data["t"] = range(len(akmola_data))  # 0, 1, 2, ..., N

# # Trend line
# coeffs = np.polyfit(akmola_data["t"], akmola_data["Объем"], deg=1)
# trend = np.poly1d(coeffs)

# # Moving Averages
# akmola_data["MA_12"] = akmola_data["Объем"].rolling(window=12, center=True).mean()

# # Plot
# plt.figure(figsize=(14, 6))

# # Actual data
# plt.plot(akmola_data["Месяц"], akmola_data["Объем"], label="Фактические данные", color="steelblue")

# # Trend line
# plt.plot(akmola_data["Месяц"], trend(akmola_data["t"]), linestyle="--", color="red", label="Линейный тренд")

# # Moving Averages
# plt.plot(akmola_data["Месяц"], akmola_data["MA_12"], linestyle=":", color="green", label="Скользящее среднее (12 мес.)")

# # Labels and style
# plt.title("АКМОЛИНСКАЯ ОБЛАСТЬ — Временной ряд с трендом и скользящими средними")
# plt.xlabel("Месяц")
# plt.ylabel("Объем")
# plt.xticks(rotation=45)
# plt.grid(True)
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
# # Filter for national level
# kyzylorda_data = df_stats[df_stats["Регион"] == "КЫЗЫЛОРДИНСКАЯ ОБЛАСТЬ"].copy()

# # Ensure 'Месяц' is datetime
# kyzylorda_data["Месяц"] = pd.to_datetime(kyzylorda_data["Месяц"])

# # Create time index as integer (months since start)
# kyzylorda_data = kyzylorda_data.sort_values("Месяц")
# kyzylorda_data["t"] = range(len(kyzylorda_data))  # 0, 1, 2, ..., N

# # Trend line
# coeffs = np.polyfit(kyzylorda_data["t"], kyzylorda_data["Объем"], deg=1)
# trend = np.poly1d(coeffs)

# # Moving Averages
# kyzylorda_data["MA_12"] = kyzylorda_data["Объем"].rolling(window=12, center=True).mean()

# # Plot
# plt.figure(figsize=(14, 6))

# # Actual data
# plt.plot(kyzylorda_data["Месяц"], kyzylorda_data["Объем"], label="Фактические данные", color="steelblue")

# # Trend line
# plt.plot(kyzylorda_data["Месяц"], trend(kyzylorda_data["t"]), linestyle="--", color="red", label="Линейный тренд")

# # Moving Averages
# plt.plot(kyzylorda_data["Месяц"], kyzylorda_data["MA_12"], linestyle=":", color="green", label="Скользящее среднее (12 мес.)")

# # Labels and style
# plt.title("КЫЗЫЛОРДИНСКАЯ ОБЛАСТЬ — Временной ряд с трендом и скользящими средними")
# plt.xlabel("Месяц")
# plt.ylabel("Объем")
# plt.xticks(rotation=45)
# plt.grid(True)
# plt.legend()
# plt.tight_layout()
# plt.show()
