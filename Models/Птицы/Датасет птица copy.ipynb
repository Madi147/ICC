# %% [markdown]
# ### Подготовка датасета по показателю объем убоя домашней птицы

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
from statsmodels.graphics.tsaplots import plot_acf
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

from pylab import rcParams
from IPython.display import display
import math
from prophet import Prophet
pd.set_option('display.max_columns', 130)


import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter("ignore", category=InterpolationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
df = pd.read_excel("../../Data cleansing/output data/Просуммированные по категориям v2.xlsx")
df.head(5)
# Out:
#   Показатель                          Регион  2015-01  2015-02  2015-03  \
# 0   Верблюды             АКМОЛИНСКАЯ ОБЛАСТЬ      NaN      NaN     0.40
# 1   Верблюды             АКТЮБИНСКАЯ ОБЛАСТЬ   101.98    67.47   374.84
# 2   Верблюды             АЛМАТИНСКАЯ ОБЛАСТЬ     1.00     0.20    51.60
# 3   Верблюды              АТЫРАУСКАЯ ОБЛАСТЬ   213.89   167.70   306.60
# 4   Верблюды  ВОСТОЧНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ     0.30      NaN      NaN
#
#    2015-04  2015-05  2015-06  2015-07  2015-08  2015-09  2015-10  2015-11  \
# 0      NaN      NaN      NaN     0.09     1.00      NaN      NaN     0.20
# 1   115.59   218.72    14.15    19.77     3.00    39.16    46.16   238.56
# 2    25.40      NaN    61.90    76.87    95.57    16.09     0.10    10.80
# 3   164.97   342.57   192.00    43.60   113.03   262.37   193.97   308.17
# 4     1.14     6.12     4.70     4.20     1.80     1.80      NaN     6.82
#
#    2015-12  2016-01  2016-02  2016-03  2016-04  2016-05  2016-06  2016-07  \
# 0      NaN      NaN     0.18     0.28      NaN      NaN     0.40      NaN
# 1   463.35   109.04    72.94   384.96   114.35   221.89    10.93    18.79
# 2    46.78    15.06    13.70   131.80     9.20    17.89   130.12     2.00
# 3  1087.33   325.10   190.60   301.10   154.84   328.50   220.30    66.10
# 4    18.78     0.74      NaN     1.80     2.38     1.22     2.40     3.20
#
#    2016-08  2016-09  2016-10  2016-11  2016-12  2017-01  2017-02  2017-03  \
# 0      NaN     0.65      NaN     0.31     1.00      NaN      NaN      NaN
# 1     3.50    38.53    46.64   216.08   472.07   110.32    68.17   380.15
# 2      NaN     4.99     2.06     4.90    44.48    15.06    23.94    41.60
# 3   118.20   234.90   196.51   270.92   974.18   303.30   167.41   323.54
# 4     2.45     0.90     2.20     0.74    12.46     0.74     2.70     1.80
#
#    2017-04  2017-05  2017-06  2017-07  2017-08  2017-09  2017-10  2017-11  \
# 0      NaN      NaN     2.01      NaN     1.20      NaN      NaN     2.18
# 1   127.12   217.61    14.98    21.26     7.14    44.63    51.78   239.43
# 2    19.54     3.00    15.14    18.50    14.82    14.52    12.60     9.92
# 3   182.34   349.10   249.40    57.57    88.40   221.21   199.63   278.80
# 4      NaN      NaN     3.00      NaN      NaN     0.90     7.58     1.85
#
#    2017-12  2018-01  2018-02  2018-03  2018-04  2018-05  2018-06  2018-07  \
# 0     0.39      NaN      NaN     1.04      NaN     0.14     2.08      NaN
# 1   513.33   115.70    69.40   371.53   130.17   218.41    14.59    21.76
# 2    43.11    20.72     2.96    15.24      NaN     1.00    20.03     3.44
\
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1   121.01   223.46    11.76    21.39     5.52    48.18    61.39   150.87
# 2    12.10    12.44     6.85    39.65    17.22     8.85    27.48     0.48
# 3   182.63   414.56   405.19   184.80   154.96   717.92   719.01   522.83
# 4     0.40      NaN      NaN      NaN     0.30      NaN      NaN     0.70
#
#    2023-12  2024-01  2024-02  2024-03  2024-04  2024-05  2024-06  2024-07  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1   531.79   119.50    72.60    391.0    126.1   229.10     12.2    24.10
# 2    29.72    18.90    17.40     12.5     16.4    11.60     16.7    15.70
# 3  1164.77   323.81   423.76    441.9    219.1   487.69    446.9   191.43
# 4     0.50      NaN      NaN      NaN      0.8      NaN      NaN     0.50
#
#    2024-08  2024-09  2024-10  2024-11  2024-12  2025-01  2025-02  2025-03  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      5.7    49.87    63.00    154.3   538.40    129.3    77.60    411.5
# 2     24.0     7.70     6.90      5.4    12.60     22.6    19.00      8.2
# 3    133.5   730.34   709.68    537.6   930.28    322.1   286.54    447.4
# 4      NaN      NaN     0.40      NaN      NaN      NaN     0.70      NaN
#
#    2025-04  2025-05  2025-06  2025-07
# 0      NaN      NaN      NaN      NaN
# 1    128.1   235.70     12.2    25.17
# 2     12.0    40.70     41.6    28.10
# 3    266.8   496.55    688.0   212.70
# 4      2.9     0.90      NaN     0.60

# %%
df['Показатель'].unique()
# Out:
# array(['Верблюды', 'КРС', 'Лошади', 'Молоко', 'Овцы и козы', 'Птица',
#        'Свиньи', 'Яйца'], dtype=object)

# %%
df_bird = df[df['Показатель'].isin(['Птица'])]
df_bird.head()
# Out:
#     Показатель                          Регион  2015-01  2015-02  2015-03  \
# 100      Птица             АКМОЛИНСКАЯ ОБЛАСТЬ   672.81   658.57   469.77
# 101      Птица             АКТЮБИНСКАЯ ОБЛАСТЬ   230.70   221.98   149.84
# 102      Птица             АЛМАТИНСКАЯ ОБЛАСТЬ  5624.73  5349.54  6376.58
# 103      Птица              АТЫРАУСКАЯ ОБЛАСТЬ      NaN      NaN      NaN
# 104      Птица  ВОСТОЧНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ  3619.09  3704.07  3782.03
#
#      2015-04  2015-05  2015-06  2015-07  2015-08  2015-09  2015-10  2015-11  \
# 100   813.94   534.59   772.47   807.17   852.52  1056.11  1273.47  1092.41
# 101   213.60   162.91    42.10   226.90   353.10   259.97   320.37   425.01
# 102  6177.95  5994.10  7348.90  9177.65  6395.81  6796.17  7227.40  7430.24
# 103     0.07     1.37      NaN     0.60      NaN     0.98     0.40     0.40
# 104  4049.24  4034.68  3525.87  3419.28  3759.90  3652.82  3648.71  3960.96
#
#       2015-12  2016-01  2016-02  2016-03  2016-04  2016-05  2016-06  2016-07  \
# 100   1370.53  1212.69   995.62  1441.97  1074.47  1215.65  1481.78  1479.39
# 101    716.37   222.82   170.25   285.46   416.85   286.50   252.40   230.42
# 102  14096.10  7208.81  7351.93  7272.70  7273.35  6956.71  7380.52  5906.20
# 103      0.50     1.00      NaN      NaN     0.07     0.33      NaN     0.50
# 104   4343.45  4302.37  3820.52  4352.64  4125.18  4259.79  4348.26  3931.13
NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 104   6217.87   6956.45   6264.30   5826.35   6144.41   5613.89   6157.31
#
#       2024-11   2024-12   2025-01   2025-02   2025-03   2025-04   2025-05  \
# 100   8665.21  11438.74   8560.30  12551.51  12385.30  13015.90  10609.00
# 101     61.30    254.20     54.30     30.50     18.00     48.60     23.90
# 102  12546.48  12207.96  12023.33  10821.10  12752.96  13346.82  11619.21
# 103       NaN      0.60       NaN       NaN       NaN       NaN       NaN
# 104   6043.79   5998.19   6376.96   5574.81   6469.33   6486.09   6221.83
#
#       2025-06   2025-07
# 100  10408.60  10639.70
# 101     52.40     60.60
# 102  10505.14  10844.25
# 103       NaN       NaN
# 104   6069.31   6186.68

# %%
period_cols = [c for c in df_bird.columns if c not in ["Показатель", "Регион"]]
missing_matrix = (
    df_bird.set_index("Регион")[period_cols]
          .isna()
          .astype(int)
)
plt.figure(figsize=(16, 8))
sns.heatmap(
    missing_matrix,
    cmap=["#2b6bba", "#d7191c"],   # blue = data present, red = missing
    cbar=False,
    linewidths=0.3,
    linecolor="grey"
)

plt.title("Missing Values Heatmap – Молоко")
plt.xlabel("Time Periods")
plt.ylabel("Regions")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
df_bird.groupby("Регион").apply(lambda g: g.isna().sum().sum())
# Out:
# Регион
# АКМОЛИНСКАЯ ОБЛАСТЬ                 0
# АКТЮБИНСКАЯ ОБЛАСТЬ                 0
# АЛМАТИНСКАЯ ОБЛАСТЬ                 0
# АТЫРАУСКАЯ ОБЛАСТЬ                 66
# ВОСТОЧНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ      0
# ГАЛМАТЫ                            56
# ГАСТАНА                            40
# ГШЫМКЕНТ                           41
# ЖАМБЫЛСКАЯ ОБЛАСТЬ                  0
# ЗАПАДНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ       0
# КАРАГАНДИНСКАЯ ОБЛАСТЬ              0
# КОСТАНАЙСКАЯ ОБЛАСТЬ                0
# КЫЗЫЛОРДИНСКАЯ ОБЛАСТЬ              1
# МАНГИСТАУСКАЯ ОБЛАСТЬ              51
# ОБЛАСТЬ АБАЙ                       89
# ОБЛАСТЬ ЖЕТІСУ                     89
# ОБЛАСТЬ ҰЛЫТАУ                    101
# ПАВЛОДАРСКАЯ ОБЛАСТЬ                0
# СЕВЕРО-КАЗАХСТАНСКАЯ ОБЛАСТЬ        0
# ТУРКЕСТАНСКАЯ ОБЛАСТЬ              41
# dtype: int64

# %%
# Step 1: Pivot to wide format (each indicator becomes columns of periods)
df_wide = df_bird.pivot(index="Регион", columns="Показатель")

# Step 2: Flatten multi-level columns: ('2015-01', 'КРС') → 'КРС_2015-01'
df_wide.columns = [f"{col[1]}_{col[0]}" for col in df_wide.columns]
df_wide = df_wide.reset_index()

# Step 3: Melt: one row per region-period-indicator
df_melted = df_wide.melt(id_vars="Регион", var_name="indicator_period", value_name="value")

# Step 4: Extract 'Период' and 'Показатель' from the combined column
df_melted["Период"] = df_melted["indicator_period"].str.extract(r"_(\d{4}-\d{2})$")
df_melted["Показатель"] = df_melted["indicator_period"].str.extract(r"^(.+)_\d{4}-\d{2}")

# Step 5: Pivot again to get final modeling format: one row per region+period, one column per indicator
df_bird = df_melted.pivot_table(index=["Регион", "Период"], columns="Показатель", values="value").reset_index()
print(df_bird.groupby("Регион").size().reset_index(name="Количество строк"))
df_bird
# Out:
#                             Регион  Количество строк
# 0              АКМОЛИНСКАЯ ОБЛАСТЬ               127
# 1              АКТЮБИНСКАЯ ОБЛАСТЬ               127
# 2              АЛМАТИНСКАЯ ОБЛАСТЬ               127
# 3               АТЫРАУСКАЯ ОБЛАСТЬ                61
# 4   ВОСТОЧНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ               127
# 5                          ГАЛМАТЫ                71
# 6                          ГАСТАНА                87
# 7                         ГШЫМКЕНТ                86
# 8               ЖАМБЫЛСКАЯ ОБЛАСТЬ               127
# 9    ЗАПАДНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ               127
# 10          КАРАГАНДИНСКАЯ ОБЛАСТЬ               127
# 11            КОСТАНАЙСКАЯ ОБЛАСТЬ               127
# 12          КЫЗЫЛОРДИНСКАЯ ОБЛАСТЬ               126
# 13           МАНГИСТАУСКАЯ ОБЛАСТЬ                76
# 14                    ОБЛАСТЬ АБАЙ                38
# 15                  ОБЛАСТЬ ЖЕТІСУ                38
# 16                  ОБЛАСТЬ ҰЛЫТАУ                26
# 17            ПАВЛОДАРСКАЯ ОБЛАСТЬ               127
# 18    СЕВЕРО-КАЗАХСТАНСКАЯ ОБЛАСТЬ               127
# 19           ТУРКЕСТАНСКАЯ ОБЛАСТЬ                86
# Показатель                 Регион   Период   Птица
# 0             АКМОЛИНСКАЯ ОБЛАСТЬ  2015-01  672.81
# 1             АКМОЛИНСКАЯ ОБЛАСТЬ  2015-02  658.57
# 2             АКМОЛИНСКАЯ ОБЛАСТЬ  2015-03  469.77
# 3             АКМОЛИНСКАЯ ОБЛАСТЬ  2015-04  813.94
# 4             АКМОЛИНСКАЯ ОБЛАСТЬ  2015-05  534.59
# ...                           ...      ...     ...
# 1960        ТУРКЕСТАНСКАЯ ОБЛАСТЬ  2025-03  802.30
# 1961        ТУРКЕСТАНСКАЯ ОБЛАСТЬ  2025-04  750.07
# 1962        ТУРКЕСТАНСКАЯ ОБЛАСТЬ  2025-05  754.31
# 1963        ТУРКЕСТАНСКАЯ ОБЛАСТЬ  2025-06  925.67
# 1964        ТУРКЕСТАНСКАЯ ОБЛАСТЬ  2025-07  627.60
#
# [1965 rows x 3 columns]

# %%
df_bird['Регион'].nunique()
# Out:
# 20

# %%
df_bird.to_excel("Датасет по птице v2.xlsx", index=False)

# %%
# 1) приведение типов
df = df_bird.copy()
df["Период"] = pd.to_datetime(df["Период"], format="%Y-%m", errors="coerce")
df["Птица"] = pd.to_numeric(df["Птица"], errors="coerce")

# 2) wide-таблица: строки — месяцы, столбцы — регионы, значения — КРС
df_bird_wide = (df
        .pivot_table(index="Период", columns="Регион", values="Птица", aggfunc="sum")  # если дублей нет — можно aggfunc="first"
        .sort_index())
# 3) Убираем лишний уровень индекса у колонок
df_bird_wide.columns.name = None

# 4) Возвращаем "Период" в строковый формат YYYY-MM
df_bird_wide = df_bird_wide.reset_index()
df_bird_wide["Период"] = df_bird_wide["Период"].dt.strftime("%Y-%m")

df_bird_wide.to_excel("Датасет по птице wide.xlsx", index=False)
df_bird_wide
