# %% [markdown]
# ## Time-series Analysis & Stationarity Check

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf
from pylab import rcParams
from IPython.display import display
import math

import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter("ignore", category=InterpolationWarning)

# %% [markdown]
# #### Data preparation

# %%
df = pd.read_excel("Данные-рус Обработанные.xlsx")
df.head(5)
# Out:
#    Unnamed: 0           Unnamed: 1               Unnamed: 2  \
# 0         NaN                  NaN                      NaN
# 1         NaN                  NaN                      NaN
# 2  Показатель  Категория хозяйства                   Регион
# 3         КРС   Сельхозпредприятия     РЕСПУБЛИКА КАЗАХСТАН
# 4         КРС   Сельхозпредприятия      АКМОЛИНСКАЯ ОБЛАСТЬ
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2  2015-01-01 00:00:00  2015-02-01 00:00:00  2015-03-01 00:00:00
# 3              3400.96               3685.9              4154.43
# 4               514.75               497.95               863.93
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2  2015-04-01 00:00:00  2015-05-01 00:00:00  2015-06-01 00:00:00
# 3              5203.94              5084.05              6718.83
# 4               667.81               633.39               600.86
#
#             Unnamed: 9  ...         Unnamed: 113         Unnamed: 114  \
# 0                  NaN  ...                  NaN                  NaN
# 1                  NaN  ...                  NaN                  NaN
# 2  2015-07-01 00:00:00  ...  2024-03-01 00:00:00  2024-04-01 00:00:00
# 3              4235.03  ...              9703.45             11165.56
# 4               875.47  ...               978.41              1071.35
#
#           Unnamed: 115         Unnamed: 116         Unnamed: 117  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2  2024-05-01 00:00:00  2024-06-01 00:00:00  2024-07-01 00:00:00
# 3              8179.14             24407.52              9835.22
# 4              1067.76              1119.61               898.07
#
#           Unnamed: 118         Unnamed: 119         Unnamed: 120  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2  2024-08-01 00:00:00  2024-09-01 00:00:00  2024-10-01 00:00:00
# 3             11955.41             16955.56             10638.42
# 4                 1382              1133.36              1073.27
#
#           Unnamed: 121         Unnamed: 122
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# 2  2024-11-01 00:00:00  2024-12-01 00:00:00
# 3              9612.92              21521.5
# 4              1118.19              1332.88
#
# [5 rows x 123 columns]

# %%
# remove first two rows (blank)
df = df.drop(index=df.index[:2]).reset_index(drop=True)
df.head(5)
# Out:
#    Unnamed: 0           Unnamed: 1               Unnamed: 2  \
# 0  Показатель  Категория хозяйства                   Регион
# 1         КРС   Сельхозпредприятия     РЕСПУБЛИКА КАЗАХСТАН
# 2         КРС   Сельхозпредприятия      АКМОЛИНСКАЯ ОБЛАСТЬ
# 3         КРС   Сельхозпредприятия      АКТЮБИНСКАЯ ОБЛАСТЬ
# 4         КРС   Сельхозпредприятия      АЛМАТИНСКАЯ ОБЛАСТЬ
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0  2015-01-01 00:00:00  2015-02-01 00:00:00  2015-03-01 00:00:00
# 1              3400.96               3685.9              4154.43
# 2               514.75               497.95               863.93
# 3               554.41               504.35               493.56
# 4                178.3               362.86               352.49
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# 0  2015-04-01 00:00:00  2015-05-01 00:00:00  2015-06-01 00:00:00
# 1              5203.94              5084.05              6718.83
# 2               667.81               633.39               600.86
# 3               445.51               585.79               316.47
# 4               451.79               228.32               708.84
#
#             Unnamed: 9  ...         Unnamed: 113         Unnamed: 114  \
# 0  2015-07-01 00:00:00  ...  2024-03-01 00:00:00  2024-04-01 00:00:00
# 1              4235.03  ...              9703.45             11165.56
# 2               875.47  ...               978.41              1071.35
# 3               469.49  ...              1520.51              1747.09
# 4               280.55  ...              1055.43               110.45
#
#           Unnamed: 115         Unnamed: 116         Unnamed: 117  \
# 0  2024-05-01 00:00:00  2024-06-01 00:00:00  2024-07-01 00:00:00
# 1              8179.14             24407.52              9835.22
# 2              1067.76              1119.61               898.07
# 3                915.8              1851.96               932.63
# 4               188.15               172.63               112.31
#
#           Unnamed: 118         Unnamed: 119         Unnamed: 120  \
# 0  2024-08-01 00:00:00  2024-09-01 00:00:00  2024-10-01 00:00:00
# 1             11955.41             16955.56             10638.42
# 2                 1382              1133.36              1073.27
# 3               945.11              1142.92              1637.64
# 4               134.99              1212.02               260.02
#
#           Unnamed: 121         Unnamed: 122
# 0  2024-11-01 00:00:00  2024-12-01 00:00:00
# 1              9612.92              21521.5
# 2              1118.19              1332.88
# 3              1180.54              1045.69
# 4               129.38               159.66
#
# [5 rows x 123 columns]

# %%
# Set the first row as column labels
df.columns = df.iloc[0]  # Assign first row as header
df = df[1:].reset_index(drop=True)  # Drop the first row and reset index
df.sample(5)
# Out:
# 0     Показатель                    Категория хозяйства  \
# 106  Овцы и козы  Крестьянские или фермерские хозяйства
# 18           КРС                     Сельхозпредприятия
# 350        Птицы                     Сельхозпредприятия
# 133       Свиньи                     Сельхозпредприятия
# 339        Птицы                     Сельхозпредприятия
#
# 0                        Регион 2015-01-01 00:00:00 2015-02-01 00:00:00  \
# 106       ТУРКЕСТАНСКАЯ ОБЛАСТЬ                 нет                 нет
# 18        ТУРКЕСТАНСКАЯ ОБЛАСТЬ                 нет                 нет
# 350              ОБЛАСТЬ ҰЛЫТАУ                 нет                 нет
# 133         АКМОЛИНСКАЯ ОБЛАСТЬ               72.32               44.44
# 339      КЫЗЫЛОРДИНСКАЯ ОБЛАСТЬ                   0                 NaN
#
# 0   2015-03-01 00:00:00 2015-04-01 00:00:00 2015-05-01 00:00:00  \
# 106                 нет                 нет                 нет
# 18                  нет                 нет                 нет
# 350                 нет                 нет                 нет
# 133               81.59              117.04              146.62
# 339                 NaN                 NaN                 NaN
#
# 0   2015-06-01 00:00:00 2015-07-01 00:00:00  ... 2024-03-01 00:00:00  \
# 106                 нет                 нет  ...               471.4
# 18                  нет                 нет  ...             1366.07
# 350                 нет                 нет  ...                 NaN
# 133              114.41              105.97  ...                6.94
# 339                 NaN                 NaN  ...                   0
#
# 0   2024-04-01 00:00:00 2024-05-01 00:00:00 2024-06-01 00:00:00  \
# 106               475.1               369.7               460.2
# 18              4009.21             1575.56            10529.94
# 350                 NaN                 NaN                 NaN
# 133                6.55                6.74               17.26
# 339                   0                   0                 NaN
#
# 0   2024-07-01 00:00:00 2024-08-01 00:00:00 2024-09-01 00:00:00  \
# 106               450.4               409.8               442.3
# 18              1593.86             4331.39             8049.47
# 350                 NaN                 NaN                 NaN
# 133               12.39               16.33               16.16
# 339                   0                 NaN               30.41
#
# 0   2024-10-01 00:00:00 2024-11-01 00:00:00 2024-12-01 00:00:00
# 106                 380               792.4              871.59
# 18               2910.8             2821.28            13033.74
# 350                 NaN                 NaN                 NaN
# 133               16.45                9.79               22.95
# 339                 NaN                 NaN               39.46
#
# [5 rows x 123 columns]

# %%
df["Регион"].unique()
# Out:
# array(['РЕСПУБЛИКА КАЗАХСТАН', '    АКМОЛИНСКАЯ ОБЛАСТЬ',
#        '    АКТЮБИНСКАЯ ОБЛАСТЬ', '    АЛМАТИНСКАЯ ОБЛАСТЬ',
#        '    АТЫРАУСКАЯ ОБЛАСТЬ', '    ЗАПАДНО0КАЗАХСТАНСКАЯ ОБЛАСТЬ',
#        '    ЖАМБЫЛСКАЯ ОБЛАСТЬ', '    КАРАГАНДИНСКАЯ ОБЛАСТЬ',
#        '    КОСТАНАЙСКАЯ ОБЛАСТЬ', '    КЫЗЫЛОРДИНСКАЯ ОБЛАСТЬ',
#        '    МАНГИСТАУСКАЯ ОБЛАСТЬ', '    ЮЖНО0КАЗАХСТАНСКАЯ ОБЛАСТЬ',
#        '    ПАВЛОДАРСКАЯ ОБЛАСТЬ', '    СЕВЕРО0КАЗАХСТАНСКАЯ ОБЛАСТЬ',
#        '    ВОСТОЧНО0КАЗАХСТАНСКАЯ ОБЛАСТЬ', '    ГАСТАНА', '    ГАЛМАТЫ',
#        '    ГШЫМКЕНТ', '    ТУРКЕСТАНСКАЯ ОБЛАСТЬ', '    ОБЛАСТЬ ЖЕТІСУ',
#        '    ОБЛАСТЬ ҰЛЫТАУ', '    ОБЛАСТЬ АБАЙ'], dtype=object)

# %%
df["Регион"] = df["Регион"].str.strip()
rename_dict = {
    "ВОСТОЧНО0КАЗАХСТАНСКАЯ ОБЛАСТЬ": "ВОСТОЧНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ", 
    "ГАЛМАТЫ": "ГОРОД АЛМАТЫ",
    "ГАСТАНА": "ГОРОД АСТАНА",
    "ГШЫМКЕНТ": "ГОРОД ШЫМКЕНТ",  
    "ЗАПАДНО0КАЗАХСТАНСКАЯ ОБЛАСТЬ": "ЗАПАДНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ",
    "СЕВЕРО0КАЗАХСТАНСКАЯ ОБЛАСТЬ": "СЕВЕРО-КАЗАХСТАНСКАЯ ОБЛАСТЬ",
    "ЮЖНО0КАЗАХСТАНСКАЯ ОБЛАСТЬ": "ЮЖНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ",  
}

# Rename regions in the index
df["Регион"] = df["Регион"].replace(rename_dict)

df["Регион"].unique()
# Out:
# array(['РЕСПУБЛИКА КАЗАХСТАН', 'АКМОЛИНСКАЯ ОБЛАСТЬ',
#        'АКТЮБИНСКАЯ ОБЛАСТЬ', 'АЛМАТИНСКАЯ ОБЛАСТЬ', 'АТЫРАУСКАЯ ОБЛАСТЬ',
#        'ЗАПАДНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ', 'ЖАМБЫЛСКАЯ ОБЛАСТЬ',
#        'КАРАГАНДИНСКАЯ ОБЛАСТЬ', 'КОСТАНАЙСКАЯ ОБЛАСТЬ',
#        'КЫЗЫЛОРДИНСКАЯ ОБЛАСТЬ', 'МАНГИСТАУСКАЯ ОБЛАСТЬ',
#        'ЮЖНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ', 'ПАВЛОДАРСКАЯ ОБЛАСТЬ',
#        'СЕВЕРО-КАЗАХСТАНСКАЯ ОБЛАСТЬ', 'ВОСТОЧНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ',
#        'ГОРОД АСТАНА', 'ГОРОД АЛМАТЫ', 'ГОРОД ШЫМКЕНТ',
#        'ТУРКЕСТАНСКАЯ ОБЛАСТЬ', 'ОБЛАСТЬ ЖЕТІСУ', 'ОБЛАСТЬ ҰЛЫТАУ',
#        'ОБЛАСТЬ АБАЙ'], dtype=object)

# %%
# Filter the df
df = df[df['Показатель'] == "Птицы"]
# df = df.drop(columns=["Показатель", "Категория хозяйства"])
df.sample(5)
# Out:
# 0   Показатель                    Категория хозяйства                 Регион  \
# 369      Птицы  Крестьянские или фермерские хозяйства          ГОРОД ШЫМКЕНТ
# 360      Птицы  Крестьянские или фермерские хозяйства   КОСТАНАЙСКАЯ ОБЛАСТЬ
# 353      Птицы  Крестьянские или фермерские хозяйства    АКМОЛИНСКАЯ ОБЛАСТЬ
# 370      Птицы  Крестьянские или фермерские хозяйства  ТУРКЕСТАНСКАЯ ОБЛАСТЬ
# 340      Птицы                     Сельхозпредприятия  МАНГИСТАУСКАЯ ОБЛАСТЬ
#
# 0   2015-01-01 00:00:00 2015-02-01 00:00:00 2015-03-01 00:00:00  \
# 369                 нет                 нет                 нет
# 360              123.11                16.7                0.68
# 353                   0                 NaN                 0.2
# 370                 нет                 нет                 нет
# 340                   0                 NaN                 NaN
#
# 0   2015-04-01 00:00:00 2015-05-01 00:00:00 2015-06-01 00:00:00  \
# 369                 нет                 нет                 нет
# 360                0.65                0.18                0.53
# 353                0.06                0.09                 NaN
# 370                 нет                 нет                 нет
# 340                 NaN                 NaN                 NaN
#
# 0   2015-07-01 00:00:00  ... 2024-03-01 00:00:00 2024-04-01 00:00:00  \
# 369                 нет  ...                 0.1                 0.1
# 360                0.15  ...                 0.2                 NaN
# 353                 NaN  ...                 0.1                 0.1
# 370                 нет  ...                 0.9                 NaN
# 340                 NaN  ...              842.52              855.84
#
# 0   2024-05-01 00:00:00 2024-06-01 00:00:00 2024-07-01 00:00:00  \
# 369                 0.1                   0                 NaN
# 360                   0                 0.4                   0
# 353                 NaN                 0.1                   0
# 370                 0.6                   1                 0.7
# 340              710.09              641.57              667.37
#
# 0   2024-08-01 00:00:00 2024-09-01 00:00:00 2024-10-01 00:00:00  \
# 369                 0.1                 NaN                 0.2
# 360                 NaN                 0.2                   0
# 353                 0.1                 0.1                 0.3
# 370                   0                   0                   0
# 340              921.96               379.6              601.52
#
# 0   2024-11-01 00:00:00 2024-12-01 00:00:00
# 369                   0                   0
# 360                   0                 1.5
# 353                 0.2                 0.1
# 370                   0                   0
# 340              808.27              754.21
#
# [5 rows x 123 columns]

# %%
# Sum only the last two columns, grouped by "Регион"
df_sum = df.groupby("Регион")[df.columns[3:]].sum().reset_index()
df_sum
# Out:
# 0                           Регион 2015-01-01 00:00:00 2015-02-01 00:00:00  \
# 0              АКМОЛИНСКАЯ ОБЛАСТЬ              672.81              658.57
# 1              АКТЮБИНСКАЯ ОБЛАСТЬ               230.7              221.98
# 2              АЛМАТИНСКАЯ ОБЛАСТЬ             5624.73             5349.54
# 3               АТЫРАУСКАЯ ОБЛАСТЬ                   0                   0
# 4   ВОСТОЧНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ             3619.09             3704.07
# 5                     ГОРОД АЛМАТЫ                5.17                1.17
# 6                     ГОРОД АСТАНА                0.37                0.75
# 7                    ГОРОД ШЫМКЕНТ           нетнетнет           нетнетнет
# 8               ЖАМБЫЛСКАЯ ОБЛАСТЬ               33.04               23.17
# 9    ЗАПАДНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ               69.13               58.78
# 10          КАРАГАНДИНСКАЯ ОБЛАСТЬ              912.19              949.26
# 11            КОСТАНАЙСКАЯ ОБЛАСТЬ              479.46              352.81
# 12          КЫЗЫЛОРДИНСКАЯ ОБЛАСТЬ                   0                0.16
# 13           МАНГИСТАУСКАЯ ОБЛАСТЬ                   0                   0
# 14                    ОБЛАСТЬ АБАЙ           нетнетнет           нетнетнет
# 15                  ОБЛАСТЬ ЖЕТІСУ           нетнетнет           нетнетнет
# 16                  ОБЛАСТЬ ҰЛЫТАУ           нетнетнет           нетнетнет
# 17            ПАВЛОДАРСКАЯ ОБЛАСТЬ              155.04              227.26
# 18            РЕСПУБЛИКА КАЗАХСТАН            13687.59            12524.88
# 19    СЕВЕРО-КАЗАХСТАНСКАЯ ОБЛАСТЬ              224.71              190.76
# 20           ТУРКЕСТАНСКАЯ ОБЛАСТЬ           нетнетнет           нетнетнет
# 21      ЮЖНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ              1598.4               786.6
#
# 0  2015-03-01 00:00:00 2015-04-01 00:00:00 2015-05-01 00:00:00  \
# 0               469.77              813.94              534.59
# 1               149.84               213.6              162.91
# 2              6376.58             6177.95              5994.1
# 3                    0                0.07                1.37
# 4              3782.03             4049.24             4034.68
# 5                 0.82                1.06                0.38
# 6                 0.25                0.23                0.35
# 7            нетнетнет           нетнетнет           нетнетнет
# 8                10.32               97.76              105.32
# 9                47.85               18.02               47.11
# 10              807.54              930.49              798.69
# 11              325.56               349.5              453.98
# 12                0.62                1.07                 1.3
# 13                   0                   0                   0
# 14           нетнетнет           нетнетнет           нетнетнет
# 15           нетнетнет           нетнетнет           нетнетнет
# 16           нетнетнет           нетнетнет           нетнетнет
# 17              241.11              359.18              358.84
# 18             13759.3            14165.96            14204.92
# 19              309.31              269.35               241.3
# 20           нетнетнет           нетнетнет           нетнетнет
# 21              1237.7               884.5              1470.0
#
# 0  2015-06-01 00:00:00 2015-07-01 00:00:00 2015-08-01 00:00:00  \
# 0               772.47              807.17              852.52
# 1                 42.1               226.9               353.1
# 2               7348.9             9177.65             6395.81
# 3                    0                 0.6                   0
# 4              3525.87             3419.28              3759.9
# 5                 0.24                   0                 0.6
# 6                 0.42                0.42                1.27
# 7            нетнетнет           нетнетнет           нетнетнет
# 8                81.32               126.1               26.66
# 9                80.21                35.4               80.05
# 10              833.02              871.43              977.17
# 11              373.98              304.86              281.97
# 12                0.93                0.51                0.56
# 13                0.51                   0                   0
# 14           нетнетнет           нетнетнет           нетнетнет
# 15           нетнетнет           нетнетнет           нетнетнет
# 16           нетнетнет           нетнетнет           нетнетнет
# 17              220.44              229.31               99.21
# 18            14421.59            16582.23            13886.16
# 19               259.2              317.77              314.05
# 20           нетнетнет           нетнетнет           нетнетнет
# 21              881.98             1064.83              743.29
#
# 0  2015-09-01 00:00:00  ... 2024-03-01 00:00:00 2024-04-01 00:00:00  \
# 0              1056.11  ...            10969.85            10894.97
# 1               259.97  ...                82.4                53.6
# 2              6796.17  ...            12341.77            11359.95
# 3                 0.98  ...                   0                   0
# 4              3652.82  ...             6673.73             6217.87
# 5                 0.53  ...                 0.1                 0.1
# 6                 1.57  ...                   0                   0
# 7            нетнетнет  ...                 5.7                 4.6
# 8               136.21  ...             1289.81             1888.54
# 9                49.59  ...              815.43             1176.48
# 10               896.3  ...             1155.23               972.4
# 11              356.58  ...             1119.53             1112.85
# 12                0.66  ...                 0.8                 0.6
# 13                0.04  ...              842.52              855.84
# 14           нетнетнет  ...              2112.7              2017.5
# 15           нетнетнет  ...                 7.4               175.4
# 16           нетнетнет  ...                   0                   0
# 17               35.38  ...              279.14              309.56
# 18             14888.4  ...            38877.26            37925.08
# 19              396.09  ...              200.81              156.16
# 20           нетнетнет  ...              918.78              612.13
# 21              1249.4  ...           нетнетнет           нетнетнет
#
# 0  2024-05-01 00:00:00 2024-06-01 00:00:00 2024-07-01 00:00:00  \
# 0             10238.97            12692.46            10379.17
# 1                 37.0                46.4                52.6
# 2             11464.21            11091.93            12311.95
# 3                    0                   0                   0
# 4              6956.45              6264.3             5826.35
# 5                  0.1                 0.1                 0.1
# 6                  0.1                   0                   0
# 7                  3.5                 4.3                 4.1
# 8              1709.14              1555.1             1561.05
# 9              1135.85              902.53              1132.8
# 10             1034.85              894.67              859.41
# 11             1039.56              615.58              545.87
# 12                 0.6                 0.8                 1.3
# 13              710.09              641.57              667.37
# 14              1762.6              1722.4              1693.8
# 15               235.4               254.0               117.1
# 16                   0                   0                 9.6
# 17               261.9               145.4               401.1
# 18            36961.88            37278.97            36609.51
# 19                28.9              141.33              214.21
# 20               333.1              305.92               742.4
# 21           нетнетнет           нетнетнет           нетнетнет
#
# 0  2024-08-01 00:00:00 2024-09-01 00:00:00 2024-10-01 00:00:00  \
# 0             10080.07            10273.59            10251.41
# 1                 68.4                 1.6                65.0
# 2             11018.07            10774.72            11765.56
# 3                    0                   0                   0
# 4              6144.41             5613.89             6157.31
# 5                  0.1                 0.1                 0.1
# 6                    0                   0                   0
# 7                  3.3                 4.3                 4.9
# 8              1658.56             1816.86             2029.92
# 9               1035.3              960.03             1059.99
# 10              977.18             1036.95             1137.79
# 11             1466.16             1237.16             1259.01
# 12                 1.2               31.41                 2.1
# 13              921.96               379.6              601.52
# 14              1936.9              1862.4              1948.9
# 15                13.8                 9.8               140.7
# 16                 3.1                 8.7                 6.0
# 17               146.9               128.7              374.48
# 18            36573.77            35333.43            38227.85
# 19              397.76              482.39              731.53
# 20               700.6              711.12              691.74
# 21           нетнетнет           нетнетнет           нетнетнет
#
# 0  2024-11-01 00:00:00 2024-12-01 00:00:00
# 0              8665.21            11438.74
# 1                 61.3               254.2
# 2             12546.48            12207.96
# 3                    0                 0.6
# 4              6043.79             5998.19
# 5                  0.1                 0.1
# 6                    0                   0
# 7                  5.5                29.7
# 8              1865.53             2167.03
# 9              1226.25              991.03
# 10              934.12             1132.22
# 11             1269.69             1539.94
# 12                 1.6               41.06
# 13              808.27              754.21
# 14              2098.7              2226.0
# 15                58.1                57.2
# 16                 2.0                12.6
# 17              385.73              449.35
# 18            37148.85            40228.95
# 19              509.18              363.28
# 20               667.3              565.34
# 21           нетнетнет           нетнетнет
#
# [22 rows x 121 columns]

# %%
# convert date columns to datetime format
df_sum.columns = list(df_sum.columns[:1]) + list(pd.to_datetime(df_sum.columns[-120:]))
df_sum = df_sum.rename(columns={col: col.strftime("%Y-%m-%d") for col in df_sum.columns[-120:]})
df_sum.sample(5)
# Out:
#                            Регион 2015-01-01 2015-02-01 2015-03-01 2015-04-01  \
# 15                 ОБЛАСТЬ ЖЕТІСУ  нетнетнет  нетнетнет  нетнетнет  нетнетнет
# 9   ЗАПАДНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ      69.13      58.78      47.85      18.02
# 10         КАРАГАНДИНСКАЯ ОБЛАСТЬ     912.19     949.26     807.54     930.49
# 1             АКТЮБИНСКАЯ ОБЛАСТЬ      230.7     221.98     149.84      213.6
# 7                   ГОРОД ШЫМКЕНТ  нетнетнет  нетнетнет  нетнетнет  нетнетнет
#
#    2015-05-01 2015-06-01 2015-07-01 2015-08-01 2015-09-01  ... 2024-03-01  \
# 15  нетнетнет  нетнетнет  нетнетнет  нетнетнет  нетнетнет  ...        7.4
# 9       47.11      80.21       35.4      80.05      49.59  ...     815.43
# 10     798.69     833.02     871.43     977.17      896.3  ...    1155.23
# 1      162.91       42.1      226.9      353.1     259.97  ...       82.4
# 7   нетнетнет  нетнетнет  нетнетнет  нетнетнет  нетнетнет  ...        5.7
#
#    2024-04-01 2024-05-01 2024-06-01 2024-07-01 2024-08-01 2024-09-01  \
# 15      175.4      235.4      254.0      117.1       13.8        9.8
# 9     1176.48    1135.85     902.53     1132.8     1035.3     960.03
# 10      972.4    1034.85     894.67     859.41     977.18    1036.95
# 1        53.6       37.0       46.4       52.6       68.4        1.6
# 7         4.6        3.5        4.3        4.1        3.3        4.3
#
#    2024-10-01 2024-11-01 2024-12-01
# 15      140.7       58.1       57.2
# 9     1059.99    1226.25     991.03
# 10    1137.79     934.12    1132.22
# 1        65.0       61.3      254.2
# 7         4.9        5.5       29.7
#
# [5 rows x 121 columns]

# %%
# Replace "нетнетнет" with NaN for easier handling
df_sum.replace("нетнетнет", np.nan, inplace=True)

# Convert all values to numeric, keeping NaNs
df_sum_numeric = df_sum.set_index("Регион").apply(pd.to_numeric, errors="coerce")

# Create heatmap: 1 for missing values, 0 for present values
missing_heatmap = df_sum_numeric.isna()

# Plot heatmap
plt.figure(figsize=(16, 8))
sns.heatmap(missing_heatmap, cmap="coolwarm", cbar=False, linewidths=0.5)
plt.title('Missing Values Heatmap - Птицы (Сумма)')
plt.xlabel("Time Periods")
plt.ylabel("Regions")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_19276\2611807932.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_sum.replace("нетнетнет", np.nan, inplace=True)

# %%
# Convert from wide format to long format
df_sum_melted = df_sum.melt(id_vars=["Регион"], var_name="Месяц", value_name="Объем")
df_sum_melted.sample(5)
# Out:
#                    Регион       Месяц    Объем
# 160          ГОРОД АСТАНА  2015-08-01     1.27
# 930          ГОРОД АСТАНА  2018-07-01     0.15
# 462   АКМОЛИНСКАЯ ОБЛАСТЬ  2016-10-01  1541.00
# 1722         ГОРОД АСТАНА  2021-07-01     0.00
# 1964         ГОРОД АСТАНА  2022-06-01     0.10

# %%
# Convert date column to datetime
df_sum_melted["Месяц"] = pd.to_datetime(df_sum_melted["Месяц"])

# Set index for time-series analysis
df_sum_melted = df_sum_melted.sort_values(["Регион", "Месяц"]).set_index(["Регион", "Месяц"])

df_sum_melted
# Out:
#                                         Объем
# Регион                     Месяц
# АКМОЛИНСКАЯ ОБЛАСТЬ        2015-01-01  672.81
#                            2015-02-01  658.57
#                            2015-03-01  469.77
#                            2015-04-01  813.94
#                            2015-05-01  534.59
# ...                                       ...
# ЮЖНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ 2024-08-01     NaN
#                            2024-09-01     NaN
#                            2024-10-01     NaN
#                            2024-11-01     NaN
#                            2024-12-01     NaN
#
# [2640 rows x 1 columns]

# %%
# Replace "нет" with NaN
df_sum_melted = df_sum_melted.replace("нетнетнет", np.nan)
df_sum_melted.isna().groupby("Регион").mean() * 100
# Out:
#                                     Объем
# Регион
# АКМОЛИНСКАЯ ОБЛАСТЬ              0.000000
# АКТЮБИНСКАЯ ОБЛАСТЬ              0.000000
# АЛМАТИНСКАЯ ОБЛАСТЬ              0.000000
# АТЫРАУСКАЯ ОБЛАСТЬ               0.000000
# ВОСТОЧНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ   0.000000
# ГОРОД АЛМАТЫ                     0.000000
# ГОРОД АСТАНА                     0.000000
# ГОРОД ШЫМКЕНТ                   34.166667
# ЖАМБЫЛСКАЯ ОБЛАСТЬ               0.000000
# ЗАПАДНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ    0.000000
# КАРАГАНДИНСКАЯ ОБЛАСТЬ           0.000000
# КОСТАНАЙСКАЯ ОБЛАСТЬ             0.000000
# КЫЗЫЛОРДИНСКАЯ ОБЛАСТЬ           0.000000
# МАНГИСТАУСКАЯ ОБЛАСТЬ            0.000000
# ОБЛАСТЬ АБАЙ                    74.166667
# ОБЛАСТЬ ЖЕТІСУ                  74.166667
# ОБЛАСТЬ ҰЛЫТАУ                  74.166667
# ПАВЛОДАРСКАЯ ОБЛАСТЬ             0.000000
# РЕСПУБЛИКА КАЗАХСТАН             0.000000
# СЕВЕРО-КАЗАХСТАНСКАЯ ОБЛАСТЬ     0.000000
# ТУРКЕСТАНСКАЯ ОБЛАСТЬ           34.166667
# ЮЖНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ      65.833333

# %%
# Filter the df
df_shp = df[(df['Показатель'] == "Птицы") & (df['Категория хозяйства'] == "Сельхозпредприятия")]
df_shp = df_shp.drop(columns=["Показатель", "Категория хозяйства"])
df_shp = df_shp.sort_values(by="Регион", ascending=True)

df_shp.sample(5)
# Out:
# 0                            Регион 2015-01-01 00:00:00 2015-02-01 00:00:00  \
# 331             АКМОЛИНСКАЯ ОБЛАСТЬ              650.97              639.44
# 330            РЕСПУБЛИКА КАЗАХСТАН            13243.04            12270.11
# 341      ЮЖНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ              1501.3               683.9
# 348           ТУРКЕСТАНСКАЯ ОБЛАСТЬ                 нет                 нет
# 344  ВОСТОЧНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ              3616.7              3701.2
#
# 0   2015-03-01 00:00:00 2015-04-01 00:00:00 2015-05-01 00:00:00  \
# 331               435.8              775.27              512.46
# 330             13403.3            13794.88            13848.19
# 341              1143.5               770.7             1340.62
# 348                 нет                 нет                 нет
# 344             3765.25              4047.3              4018.3
#
# 0   2015-06-01 00:00:00 2015-07-01 00:00:00 2015-08-01 00:00:00  \
# 331              677.56               756.2              817.46
# 330            13868.34            16072.64            13436.63
# 341               807.1               976.4              635.61
# 348                 нет                 нет                 нет
# 344             3461.34             3380.02             3715.82
#
# 0   2015-09-01 00:00:00  ... 2024-03-01 00:00:00 2024-04-01 00:00:00  \
# 331              1008.9  ...            10953.45            10846.37
# 330            14140.78  ...            38738.76            37718.58
# 341              1138.5  ...                 нет                 нет
# 348                 нет  ...              877.78              561.63
# 344             3563.81  ...             6671.63             6212.87
#
# 0   2024-05-01 00:00:00 2024-06-01 00:00:00 2024-07-01 00:00:00  \
# 331            10210.37            12681.96            10327.67
# 330            36821.48            36953.97            36280.31
# 341                 нет                 нет                 нет
# 348               295.3              267.82               681.1
# 344             6955.05              6255.4             5822.25
#
# 0   2024-08-01 00:00:00 2024-09-01 00:00:00 2024-10-01 00:00:00  \
# 331            10032.07            10201.89            10113.41
# 330            36291.87            34984.23            37659.15
# 341                 нет                 нет                 нет
# 348                 643              636.62              637.24
# 344             6134.61             5602.99             6149.31
#
# 0   2024-11-01 00:00:00 2024-12-01 00:00:00
# 331             8558.21            11275.74
# 330            36492.45            38913.45
# 341                 нет                 нет
# 348                 584              486.54
# 344             6037.39             5949.29
#
# [5 rows x 121 columns]

# %%
# Replace "нетнетнет" with NaN for easier handling
df_shp.replace("нет", np.nan, inplace=True)

# Convert all values to numeric, keeping NaNs
df_shp_numeric = df_shp.set_index("Регион").apply(pd.to_numeric, errors="coerce")

# Create heatmap: 1 for missing values, 0 for present values
missing_heatmap = df_shp_numeric.isna()

# Plot heatmap
plt.figure(figsize=(16, 8))
sns.heatmap(missing_heatmap, cmap="coolwarm", cbar=False, linewidths=0.5)
plt.title('Missing Values Heatmap - Птицы, Сельхозпредприятия')
plt.xlabel("Time Periods")
plt.ylabel("Regions")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_19276\1799203455.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_shp.replace("нет", np.nan, inplace=True)

# %%
# Filter the df
df_kfh = df[(df['Показатель'] == "Птицы") & (df['Категория хозяйства'] == "Крестьянские или фермерские хозяйства")]
df_kfh = df_kfh.drop(columns=["Показатель", "Категория хозяйства"])
df_kfh = df_kfh.sort_values(by="Регион", ascending=True)

df_kfh.sample(5)
# Out:
# 0                           Регион 2015-01-01 00:00:00 2015-02-01 00:00:00  \
# 357  ЗАПАДНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ                   0                 NaN
# 363     ЮЖНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ                 NaN                 NaN
# 356             АТЫРАУСКАЯ ОБЛАСТЬ                   0                 NaN
# 355            АЛМАТИНСКАЯ ОБЛАСТЬ                   0                 NaN
# 354            АКТЮБИНСКАЯ ОБЛАСТЬ                   0                 NaN
#
# 0   2015-03-01 00:00:00 2015-04-01 00:00:00 2015-05-01 00:00:00  \
# 357                35.2                0.03                 NaN
# 363                 0.9                 0.2                 1.1
# 356                 NaN                 NaN                 1.1
# 355                 3.5                 NaN                 NaN
# 354                 NaN                 NaN                 NaN
#
# 0   2015-06-01 00:00:00 2015-07-01 00:00:00 2015-08-01 00:00:00  \
# 357                6.92                0.52                 0.9
# 363                 0.6                 NaN                0.16
# 356                 NaN                 0.6                 NaN
# 355                 NaN                 9.8                 NaN
# 354                 NaN                 NaN                 NaN
#
# 0   2015-09-01 00:00:00  ... 2024-03-01 00:00:00 2024-04-01 00:00:00  \
# 357               18.24  ...                 NaN                 NaN
# 363                 NaN  ...                 нет                 нет
# 356                 NaN  ...                 NaN                 NaN
# 355               12.61  ...                 NaN                24.3
# 354                 NaN  ...                 NaN                 NaN
#
# 0   2024-05-01 00:00:00 2024-06-01 00:00:00 2024-07-01 00:00:00  \
# 357                 NaN                 1.4                 0.1
# 363                 нет                 нет                 нет
# 356                 NaN                 NaN                 NaN
# 355                 6.7                  18                 2.8
# 354                 NaN                 NaN                   0
#
# 0   2024-08-01 00:00:00 2024-09-01 00:00:00 2024-10-01 00:00:00  \
# 357                 0.2                 1.5                 1.4
# 363                 нет                 нет                 нет
# 356                 NaN                 NaN                 NaN
# 355                12.5                 6.9                13.6
# 354                 NaN                 NaN                 0.7
#
# 0   2024-11-01 00:00:00 2024-12-01 00:00:00
# 357                 0.6                 6.2
# 363                 нет                 нет
# 356                 NaN                 0.6
# 355                10.5                10.1
# 354                 NaN                 1.5
#
# [5 rows x 121 columns]

# %%
# Replace "нетнетнет" with NaN for easier handling
df_kfh.replace("нет", np.nan, inplace=True)

# Convert all values to numeric, keeping NaNs
df_kfh_numeric = df_kfh.set_index("Регион").apply(pd.to_numeric, errors="coerce")

# Create heatmap: 1 for missing values, 0 for present values
missing_heatmap = df_kfh_numeric.isna()

# Plot heatmap
plt.figure(figsize=(16, 8))
sns.heatmap(missing_heatmap, cmap="coolwarm", cbar=False, linewidths=0.5)
plt.title('Missing Values Heatmap - Птицы, Крестьянские или фермерские хозяйства')
plt.xlabel("Time Periods")
plt.ylabel("Regions")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_19276\2700617725.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_kfh.replace("нет", np.nan, inplace=True)

# %%
# Filter the df
df_hn = df[(df['Показатель'] == "Птицы") & (df['Категория хозяйства'] == "Хозяйства населения")]
df_hn = df_hn.drop(columns=["Показатель", "Категория хозяйства"])
df_hn = df_hn.sort_values(by="Регион", ascending=True)

df_hn.sample(5)
# Out:
# 0                           Регион 2015-01-01 00:00:00 2015-02-01 00:00:00  \
# 374           РЕСПУБЛИКА КАЗАХСТАН              304.11              234.05
# 383         КЫЗЫЛОРДИНСКАЯ ОБЛАСТЬ                   0                0.16
# 375            АКМОЛИНСКАЯ ОБЛАСТЬ               21.84               19.13
# 379  ЗАПАДНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ                9.09                2.86
# 377            АЛМАТИНСКАЯ ОБЛАСТЬ                12.6                15.2
#
# 0   2015-03-01 00:00:00 2015-04-01 00:00:00 2015-05-01 00:00:00  \
# 374               310.4              367.37              347.35
# 383                0.62                1.07                 1.3
# 375               33.77               38.61               22.04
# 379                5.04                9.83                9.13
# 377                33.7                44.4                  15
#
# 0   2015-06-01 00:00:00 2015-07-01 00:00:00 2015-08-01 00:00:00  \
# 374              530.58              493.71              431.89
# 383                0.93                0.51                0.56
# 375               94.91               50.97               34.99
# 379               43.55               14.28               11.28
# 377                  40                25.9                63.7
#
# 0   2015-09-01 00:00:00  ... 2024-03-01 00:00:00 2024-04-01 00:00:00  \
# 374              706.75  ...               120.3               175.4
# 383                0.66  ...                 0.8                 0.3
# 375               47.08  ...                16.3                48.5
# 379                23.9  ...                 1.5                 4.4
# 377               39.18  ...                 0.1                 NaN
#
# 0   2024-05-01 00:00:00 2024-06-01 00:00:00 2024-07-01 00:00:00  \
# 374                 130                 289                 302
# 383                 0.6                 0.3                 0.5
# 375                28.6                10.4                51.5
# 379                   2                  14                 6.9
# 377                 7.8                  16                 1.7
#
# 0   2024-08-01 00:00:00 2024-09-01 00:00:00 2024-10-01 00:00:00  \
# 374               252.9               328.5               548.1
# 383                 0.7                   1                 1.6
# 375                47.9                71.6               137.7
# 379                 5.5                  17                26.6
# 377                 5.7                 3.8                 0.1
#
# 0   2024-11-01 00:00:00 2024-12-01 00:00:00
# 374               634.3              1280.9
# 383                 1.1                 1.6
# 375               106.8               162.9
# 379                33.7                29.3
# 377                10.8                   4
#
# [5 rows x 121 columns]

# %%
# Replace "нетнетнет" with NaN for easier handling
df_hn.replace("нет", np.nan, inplace=True)

# Convert all values to numeric, keeping NaNs
df_hn_numeric = df_hn.set_index("Регион").apply(pd.to_numeric, errors="coerce")

# Create heatmap: 1 for missing values, 0 for present values
missing_heatmap = df_hn_numeric.isna()

# Plot heatmap
plt.figure(figsize=(16, 8))
sns.heatmap(missing_heatmap, cmap="coolwarm", cbar=False, linewidths=0.5)
plt.title('Missing Values Heatmap - Птицы, Хозяйства населения')
plt.xlabel("Time Periods")
plt.ylabel("Regions")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_19276\4016030475.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_hn.replace("нет", np.nan, inplace=True)

# %%
df_sum_melted
# Out:
#                                         Объем
# Регион                     Месяц
# АКМОЛИНСКАЯ ОБЛАСТЬ        2015-01-01  672.81
#                            2015-02-01  658.57
#                            2015-03-01  469.77
#                            2015-04-01  813.94
#                            2015-05-01  534.59
# ...                                       ...
# ЮЖНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ 2024-08-01     NaN
#                            2024-09-01     NaN
#                            2024-10-01     NaN
#                            2024-11-01     NaN
#                            2024-12-01     NaN
#
# [2640 rows x 1 columns]

# %%
# Reset index if needed
df_stats = df_sum_melted.reset_index()

# Calculate basic descriptive stats for each region
region_stats = df_stats.groupby("Регион")["Объем"].agg([
    "count", "min", "max", "mean", "median", "std"
]).rename(columns={
    "count": "Кол-во значений",
    "min": "Мин.",
    "max": "Макс.",
    "mean": "Среднее",
    "median": "Медиана",
    "std": "Ст. откл."
})

# Display result
display(region_stats.sort_values(by="Среднее", ascending=False))
# Out:
#                                 Кол-во значений      Мин.     Макс.  \
# Регион
# РЕСПУБЛИКА КАЗАХСТАН                        120  12524.88  40228.95
# АЛМАТИНСКАЯ ОБЛАСТЬ                         120   4631.31  14096.10
# АКМОЛИНСКАЯ ОБЛАСТЬ                         120    469.77  12692.46
# ВОСТОЧНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ              120   2892.05   6956.45
# ОБЛАСТЬ АБАЙ                                 31   1693.80   2312.50
# ЮЖНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ                   41    614.13   1699.00
# КАРАГАНДИНСКАЯ ОБЛАСТЬ                      120    578.17   1463.42
# ТУРКЕСТАНСКАЯ ОБЛАСТЬ                        79     61.66   1646.30
# ЖАМБЫЛСКАЯ ОБЛАСТЬ                          120     10.27   2167.03
# КОСТАНАЙСКАЯ ОБЛАСТЬ                        120    281.97   1972.63
# ЗАПАДНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ               120     10.35   1293.23
# ПАВЛОДАРСКАЯ ОБЛАСТЬ                        120      1.14    958.92
# СЕВЕРО-КАЗАХСТАНСКАЯ ОБЛАСТЬ                120     28.90    943.22
# МАНГИСТАУСКАЯ ОБЛАСТЬ                       120      0.00   1510.16
# АКТЮБИНСКАЯ ОБЛАСТЬ                         120      1.60    976.40
# ГОРОД ШЫМКЕНТ                                79      3.20    318.20
# ОБЛАСТЬ ЖЕТІСУ                               31      0.43    307.94
# АТЫРАУСКАЯ ОБЛАСТЬ                          120      0.00    290.66
# ОБЛАСТЬ ҰЛЫТАУ                               31      0.00     27.25
# КЫЗЫЛОРДИНСКАЯ ОБЛАСТЬ                      120      0.00     41.06
# ГОРОД АЛМАТЫ                                120      0.00      5.17
# ГОРОД АСТАНА                                120      0.00      2.52
#
#                                      Среднее    Медиана    Ст. откл.
# Регион
# РЕСПУБЛИКА КАЗАХСТАН            24823.019667  24269.765  7489.704369
# АЛМАТИНСКАЯ ОБЛАСТЬ              8595.857833   8499.115  1795.490595
# АКМОЛИНСКАЯ ОБЛАСТЬ              5591.317750   5389.245  3679.804179
# ВОСТОЧНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ   4833.678583   4600.330   900.083687
# ОБЛАСТЬ АБАЙ                     1933.535806   1881.950   158.641315
# ЮЖНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ       1131.650976   1237.700   314.522283
# КАРАГАНДИНСКАЯ ОБЛАСТЬ            871.337583    859.500   140.211999
# ТУРКЕСТАНСКАЯ ОБЛАСТЬ             801.610380    818.370   407.399736
# ЖАМБЫЛСКАЯ ОБЛАСТЬ                761.847833    665.315   572.637948
# КОСТАНАЙСКАЯ ОБЛАСТЬ              761.618000    635.890   375.238856
# ЗАПАДНО-КАЗАХСТАНСКАЯ ОБЛАСТЬ     676.815333    873.890   434.032125
# ПАВЛОДАРСКАЯ ОБЛАСТЬ              382.615500    415.690   203.042568
# СЕВЕРО-КАЗАХСТАНСКАЯ ОБЛАСТЬ      344.941333    311.090   191.146772
# МАНГИСТАУСКАЯ ОБЛАСТЬ             239.616083      0.015   346.816295
# АКТЮБИНСКАЯ ОБЛАСТЬ               189.187833    142.350   189.457517
# ГОРОД ШЫМКЕНТ                     101.135316    101.870    88.320750
# ОБЛАСТЬ ЖЕТІСУ                     86.022258     58.100    84.873275
# АТЫРАУСКАЯ ОБЛАСТЬ                 16.865417      0.030    53.838790
# ОБЛАСТЬ ҰЛЫТАУ                      6.104194      3.680     6.467277
# КЫЗЫЛОРДИНСКАЯ ОБЛАСТЬ              3.918667      1.705     6.581047
# ГОРОД АЛМАТЫ                        0.140667      0.000     0.510361
# ГОРОД АСТАНА                        0.132167      0.030     0.338422

# %%
# Filter for national level
national_data = df_stats[df_stats["Регион"] == "РЕСПУБЛИКА КАЗАХСТАН"].copy()

# Ensure 'Месяц' is datetime
national_data["Месяц"] = pd.to_datetime(national_data["Месяц"])

# Create time index as integer (months since start)
national_data = national_data.sort_values("Месяц")
national_data["t"] = range(len(national_data))  # 0, 1, 2, ..., N

# Trend line
coeffs = np.polyfit(national_data["t"], national_data["Объем"], deg=1)
trend = np.poly1d(coeffs)

# Moving Averages
national_data["MA_12"] = national_data["Объем"].rolling(window=12, center=True).mean()

# Plot
plt.figure(figsize=(14, 6))

# Actual data
plt.plot(national_data["Месяц"], national_data["Объем"], label="Фактические данные", color="steelblue")

# Trend line
plt.plot(national_data["Месяц"], trend(national_data["t"]), linestyle="--", color="red", label="Линейный тренд")

# Moving Averages
plt.plot(national_data["Месяц"], national_data["MA_12"], linestyle=":", color="green", label="Скользящее среднее (12 мес.)")

# Labels and style
plt.title("Птицы, РЕСПУБЛИКА КАЗАХСТАН — Временной ряд с трендом и скользящими средними")
plt.xlabel("Месяц")
plt.ylabel("Объем")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Aggregate by year (sum)
national_data["Год"] = national_data["Месяц"].dt.year
annual_data = national_data.groupby("Год")["Объем"].sum().reset_index()

# Plot
plt.figure(figsize=(10, 5))

# Actual yearly data
plt.plot(annual_data["Год"], annual_data["Объем"], marker='o', label="Годовые суммы", color="steelblue")

# Labels and style
plt.title("Птицы, РЕСПУБЛИКА КАЗАХСТАН — Годовые данные")
plt.xlabel("Год")
plt.ylabel("Суммарный объем за год")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# # Filter for national level
# aktobe_data = df_stats[df_stats["Регион"] == "АКТЮБИНСКАЯ ОБЛАСТЬ"].copy()

# # Ensure 'Месяц' is datetime
# aktobe_data["Месяц"] = pd.to_datetime(aktobe_data["Месяц"])

# # Create time index as integer (months since start)
# aktobe_data = aktobe_data.sort_values("Месяц")
# aktobe_data["t"] = range(len(aktobe_data))  # 0, 1, 2, ..., N

# # Trend line
# coeffs = np.polyfit(aktobe_data["t"], aktobe_data["Объем"], deg=1)
# trend = np.poly1d(coeffs)

# # Moving Averages
# aktobe_data["MA_12"] = aktobe_data["Объем"].rolling(window=12, center=True).mean()

# # Plot
# plt.figure(figsize=(14, 6))

# # Actual data
# plt.plot(aktobe_data["Месяц"], aktobe_data["Объем"], label="Фактические данные", color="steelblue")

# # Trend line
# plt.plot(aktobe_data["Месяц"], trend(aktobe_data["t"]), linestyle="--", color="red", label="Линейный тренд")

# # Moving Averages
# plt.plot(aktobe_data["Месяц"], aktobe_data["MA_12"], linestyle=":", color="green", label="Скользящее среднее (12 мес.)")

# # Labels and style
# plt.title("АКТЮБИНСКАЯ ОБЛАСТЬ — Временной ряд с трендом и скользящими средними")
# plt.xlabel("Месяц")
# plt.ylabel("Объем")
# plt.xticks(rotation=45)
# plt.grid(True)
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
# # Filter for national level
# akmola_data = df_stats[df_stats["Регион"] == "АКМОЛИНСКАЯ ОБЛАСТЬ"].copy()

# # Ensure 'Месяц' is datetime
# akmola_data["Месяц"] = pd.to_datetime(akmola_data["Месяц"])

# # Create time index as integer (months since start)
# akmola_data = akmola_data.sort_values("Месяц")
# akmola_data["t"] = range(len(akmola_data))  # 0, 1, 2, ..., N

# # Trend line
# coeffs = np.polyfit(akmola_data["t"], akmola_data["Объем"], deg=1)
# trend = np.poly1d(coeffs)

# # Moving Averages
# akmola_data["MA_12"] = akmola_data["Объем"].rolling(window=12, center=True).mean()

# # Plot
# plt.figure(figsize=(14, 6))

# # Actual data
# plt.plot(akmola_data["Месяц"], akmola_data["Объем"], label="Фактические данные", color="steelblue")

# # Trend line
# plt.plot(akmola_data["Месяц"], trend(akmola_data["t"]), linestyle="--", color="red", label="Линейный тренд")

# # Moving Averages
# plt.plot(akmola_data["Месяц"], akmola_data["MA_12"], linestyle=":", color="green", label="Скользящее среднее (12 мес.)")

# # Labels and style
# plt.title("АКМОЛИНСКАЯ ОБЛАСТЬ — Временной ряд с трендом и скользящими средними")
# plt.xlabel("Месяц")
# plt.ylabel("Объем")
# plt.xticks(rotation=45)
# plt.grid(True)
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
# # Filter for national level
# kyzylorda_data = df_stats[df_stats["Регион"] == "КЫЗЫЛОРДИНСКАЯ ОБЛАСТЬ"].copy()

# # Ensure 'Месяц' is datetime
# kyzylorda_data["Месяц"] = pd.to_datetime(kyzylorda_data["Месяц"])

# # Create time index as integer (months since start)
# kyzylorda_data = kyzylorda_data.sort_values("Месяц")
# kyzylorda_data["t"] = range(len(kyzylorda_data))  # 0, 1, 2, ..., N

# # Trend line
# coeffs = np.polyfit(kyzylorda_data["t"], kyzylorda_data["Объем"], deg=1)
# trend = np.poly1d(coeffs)

# # Moving Averages
# kyzylorda_data["MA_12"] = kyzylorda_data["Объем"].rolling(window=12, center=True).mean()

# # Plot
# plt.figure(figsize=(14, 6))

# # Actual data
# plt.plot(kyzylorda_data["Месяц"], kyzylorda_data["Объем"], label="Фактические данные", color="steelblue")

# # Trend line
# plt.plot(kyzylorda_data["Месяц"], trend(kyzylorda_data["t"]), linestyle="--", color="red", label="Линейный тренд")

# # Moving Averages
# plt.plot(kyzylorda_data["Месяц"], kyzylorda_data["MA_12"], linestyle=":", color="green", label="Скользящее среднее (12 мес.)")

# # Labels and style
# plt.title("КЫЗЫЛОРДИНСКАЯ ОБЛАСТЬ — Временной ряд с трендом и скользящими средними")
# plt.xlabel("Месяц")
# plt.ylabel("Объем")
# plt.xticks(rotation=45)
# plt.grid(True)
# plt.legend()
# plt.tight_layout()
# plt.show()
